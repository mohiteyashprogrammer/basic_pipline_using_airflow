# %%
import os
import sys
import pandas as pd 
import numpy as np 
import boto3
import pymysql
import mysql.connector
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
class DatabaseConnection:

    def __init__(self, host, user, password, database):
        try:
            self.connection = mysql.connector.connect(
                host=host,
                user=user,
                password=password,
                database=database
            )
            self.cursor = self.connection.cursor()

        except Exception as e:
            print(e)
    def execute_query(self, query):
        """
        Executes a SQL query and returns the results
        
        Args:
            query (str): SQL query to execute.
            
        Returns: query results.
        """
        
        try:
            self.cursor.execute(query)
            self.connection.commit()
            results = self.cursor.fetchall()  # Fetch all results
            return results
        except Exception as e:
            return f"Error executing query: {str(e)}"
        
        
    def execute_query_to_dataframe(self,query):
        """
        Executes a SQL query and returns the results as a pandas DataFrame.

        Args:
            query (str): SQL query to execute.

        Returns:
            pd.DataFrame: DataFrame containing the query results.
        """
        try:
            self.cursor.execute(query)
            results = self.cursor.fetchall()  # Fetch all results
            columns = self.cursor.column_names
            df = pd.DataFrame(results, columns=columns)
            return df

        except Exception as e:
                return f"Error executing query: {str(e)}"

        

    def insert_data_batch(self, query, data, BATCH_SIZE):
        """
        

        Args:
            query (str): This method will be take query arguments as string
            data (take data as tuple): pass data as tuple
            BATCH_SIZE (int): Give batch size acording to your needs.
        """
        try:
            
            for i in range(0, len(data), BATCH_SIZE):
                batch_data = data[i:i + BATCH_SIZE]
                self.cursor.executemany(query, batch_data)
                self.connection.commit()
                
        except Exception as e:
            print(e)
            
    def save_to_csv(self, data, file_name, path):
        
        '''
        arguments: data, file_name, path
        This method will save the data to csv file
        '''
        try:
            # create the folder if it does not exist
            if not os.path.exists(path):
                os.makedirs(path)

            # specify the full file path
            full_file_path = os.path.join(path, file_name)

            # ssave the data to a CSV file....
            data.to_csv(full_file_path, index=False)
            print(f"File '{file_name}' saved to disk in the '{path}' folder.")
        
        except Exception as e:
            print(e)
        
        
    def close(self):
        self.connection.close()
        print("close connection")

# %%
sql_executer = DatabaseConnection(
    host = os.getenv("HOST"),
    user = os.getenv("USER"),
    password = os.getenv("PASSWORD"),
    database = os.getenv("DATABASE")
)

# %%
data = sql_executer.execute_query_to_dataframe(
    query=os.getenv("QUERY"))

# %%
data.head()
# Out:
#    index  id first_name last_name                                  email  \
# 0      0   1       Paul     Casey         paul.casey.1@gslingacademy.com
# 1      1   2   Danielle  Sandoval  danielle.sandoval.2@gslingacademy.com
# 2      2   3       Tina   Andrews       tina.andrews.3@gslingacademy.com
# 3      3   4       Tara     Clark         tara.clark.4@gslingacademy.com
# 4      4   5    Anthony    Campos     anthony.campos.5@gslingacademy.com
#
#    gender  part_time_job  absence_days  extracurricular_activities  \
# 0    male              0             3                           0
# 1  female              0             2                           0
# 2  female              0             9                           1
# 3  female              0             5                           0
# 4    male              0             5                           0
#
#    weekly_self_study_hours   career_aspiration  math_score  history_score  \
# 0                       27              Lawyer          73             81
# 1                       47              Doctor          90             86
# 2                       13  Government Officer          81             97
# 3                        3              Artist          71             74
# 4                       10             Unknown          84             77
#
#    physics_score  chemistry_score  biology_score  english_score  \
# 0             93               97             63             80
# 1             96              100             90             88
# 2             95               96             65             77
# 3             88               80             89             63
# 4             65               65             80             74
#
#    geography_score
# 0               87
# 1               90
# 2               94
# 3               86
# 4               76

# %%
data.columns
# Out:
# Index(['index', 'id', 'first_name', 'last_name', 'email', 'gender',
#        'part_time_job', 'absence_days', 'extracurricular_activities',
#        'weekly_self_study_hours', 'career_aspiration', 'math_score',
#        'history_score', 'physics_score', 'chemistry_score', 'biology_score',
#        'english_score', 'geography_score'],
#       dtype='object')

# %%
data.columns[0]
# Out:
# 'index'

# %%
data[['id', 'first_name', 'last_name', 'email', 'gender',
    'part_time_job', 'absence_days', 'extracurricular_activities',
    'weekly_self_study_hours', 'career_aspiration', 'math_score',
    'history_score', 'physics_score', 'chemistry_score', 'biology_score',
    'english_score', 'geography_score']]
# Out:
#         id first_name last_name                                    email  \
# 0        1       Paul     Casey           paul.casey.1@gslingacademy.com
# 1        2   Danielle  Sandoval    danielle.sandoval.2@gslingacademy.com
# 2        3       Tina   Andrews         tina.andrews.3@gslingacademy.com
# 3        4       Tara     Clark           tara.clark.4@gslingacademy.com
# 4        5    Anthony    Campos       anthony.campos.5@gslingacademy.com
# ...    ...        ...       ...                                      ...
# 1995  1996       Alan  Reynolds     alan.reynolds.1996@gslingacademy.com
# 1996  1997     Thomas   Gilbert    thomas.gilbert.1997@gslingacademy.com
# 1997  1998    Madison     Cross     madison.cross.1998@gslingacademy.com
# 1998  1999   Brittany   Compton  brittany.compton.1999@gslingacademy.com
# 1999  2000    Natalie     Smith     natalie.smith.2000@gslingacademy.com
#
#       gender  part_time_job  absence_days  extracurricular_activities  \
# 0       male              0             3                           0
# 1     female              0             2                           0
# 2     female              0             9                           1
# 3     female              0             5                           0
# 4       male              0             5                           0
# ...      ...            ...           ...                         ...
# 1995    male              0             2                           0
# 1996    male              0             2                           0
# 1997  female              0             5                           0
# 1998  female              1            10                           1
# 1999  female              0             5                           0
#
#       weekly_self_study_hours      career_aspiration  math_score  \
# 0                          27                 Lawyer          73
# 1                          47                 Doctor          90
# 2                          13     Government Officer          81
# 3                           3                 Artist          71
# 4                          10                Unknown          84
# ...                       ...                    ...         ...
# 1995                       30  Construction Engineer          83
# 1996                       20      Software Engineer          89
# 1997                       14      Software Engineer          97
# 1998                        5         Business Owner          51
# 1999                       27             Accountant          82
#
#       history_score  physics_score  chemistry_score  biology_score  \
# 0                81             93               97             63
# 1                86             96              100             90
# 2                97             95               96             65
# 3                74             88               80             89
# 4                77             65               65             80
# ...             ...            ...              ...            ...
# 1995             77             84               73             75
# 1996             65             73               80             87
# 1997             85             63               93             68
# 1998             96             72               89             95
# 1999             99             91               69             83
#
#       english_score  geography_score
# 0                80               87
# 1                88               90
# 2                77               94
# 3                63               86
# 4                74               76
# ...             ...              ...
# 1995             84               82
# 1996             67               73
# 1997             94               78
# 1998             88               75
# 1999             93              100
#
# [2000 rows x 17 columns]

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop(data.columns[0],axis=1)
# Out:
#         id first_name last_name                                    email  \
# 0        1       Paul     Casey           paul.casey.1@gslingacademy.com
# 1        2   Danielle  Sandoval    danielle.sandoval.2@gslingacademy.com
# 2        3       Tina   Andrews         tina.andrews.3@gslingacademy.com
# 3        4       Tara     Clark           tara.clark.4@gslingacademy.com
# 4        5    Anthony    Campos       anthony.campos.5@gslingacademy.com
# ...    ...        ...       ...                                      ...
# 1995  1996       Alan  Reynolds     alan.reynolds.1996@gslingacademy.com
# 1996  1997     Thomas   Gilbert    thomas.gilbert.1997@gslingacademy.com
# 1997  1998    Madison     Cross     madison.cross.1998@gslingacademy.com
# 1998  1999   Brittany   Compton  brittany.compton.1999@gslingacademy.com
# 1999  2000    Natalie     Smith     natalie.smith.2000@gslingacademy.com
#
#       gender  part_time_job  absence_days  extracurricular_activities  \
# 0       male              0             3                           0
# 1     female              0             2                           0
# 2     female              0             9                           1
# 3     female              0             5                           0
# 4       male              0             5                           0
# ...      ...            ...           ...                         ...
# 1995    male              0             2                           0
# 1996    male              0             2                           0
# 1997  female              0             5                           0
# 1998  female              1            10                           1
# 1999  female              0             5                           0
#
#       weekly_self_study_hours      career_aspiration  math_score  \
# 0                          27                 Lawyer          73
# 1                          47                 Doctor          90
# 2                          13     Government Officer          81
# 3                           3                 Artist          71
# 4                          10                Unknown          84
# ...                       ...                    ...         ...
# 1995                       30  Construction Engineer          83
# 1996                       20      Software Engineer          89
# 1997                       14      Software Engineer          97
# 1998                        5         Business Owner          51
# 1999                       27             Accountant          82
#
#       history_score  physics_score  chemistry_score  biology_score  \
# 0                81             93               97             63
# 1                86             96              100             90
# 2                97             95               96             65
# 3                74             88               80             89
# 4                77             65               65             80
# ...             ...            ...              ...            ...
# 1995             77             84               73             75
# 1996             65             73               80             87
# 1997             85             63               93             68
# 1998             96             72               89             95
# 1999             99             91               69             83
#
#       english_score  geography_score
# 0                80               87
# 1                88               90
# 2                77               94
# 3                63               86
# 4                74               76
# ...             ...              ...
# 1995             84               82
# 1996             67               73
# 1997             94               78
# 1998             88               75
# 1999             93              100
#
# [2000 rows x 17 columns]

# %%
data
# Out:
#       index    id first_name last_name  \
# 0         0     1       Paul     Casey
# 1         1     2   Danielle  Sandoval
# 2         2     3       Tina   Andrews
# 3         3     4       Tara     Clark
# 4         4     5    Anthony    Campos
# ...     ...   ...        ...       ...
# 1995   1995  1996       Alan  Reynolds
# 1996   1996  1997     Thomas   Gilbert
# 1997   1997  1998    Madison     Cross
# 1998   1998  1999   Brittany   Compton
# 1999   1999  2000    Natalie     Smith
#
#                                         email  gender  part_time_job  \
# 0              paul.casey.1@gslingacademy.com    male              0
# 1       danielle.sandoval.2@gslingacademy.com  female              0
# 2            tina.andrews.3@gslingacademy.com  female              0
# 3              tara.clark.4@gslingacademy.com  female              0
# 4          anthony.campos.5@gslingacademy.com    male              0
# ...                                       ...     ...            ...
# 1995     alan.reynolds.1996@gslingacademy.com    male              0
# 1996    thomas.gilbert.1997@gslingacademy.com    male              0
# 1997     madison.cross.1998@gslingacademy.com  female              0
# 1998  brittany.compton.1999@gslingacademy.com  female              1
# 1999     natalie.smith.2000@gslingacademy.com  female              0
#
#       absence_days  extracurricular_activities  weekly_self_study_hours  \
# 0                3                           0                       27
# 1                2                           0                       47
# 2                9                           1                       13
# 3                5                           0                        3
# 4                5                           0                       10
# ...            ...                         ...                      ...
# 1995             2                           0                       30
# 1996             2                           0                       20
# 1997             5                           0                       14
# 1998            10                           1                        5
# 1999             5                           0                       27
#
#           career_aspiration  math_score  history_score  physics_score  \
# 0                    Lawyer          73             81             93
# 1                    Doctor          90             86             96
# 2        Government Officer          81             97             95
# 3                    Artist          71             74             88
# 4                   Unknown          84             77             65
# ...                     ...         ...            ...            ...
# 1995  Construction Engineer          83             77             84
# 1996      Software Engineer          89             65             73
# 1997      Software Engineer          97             85             63
# 1998         Business Owner          51             96             72
# 1999             Accountant          82             99             91
#
#       chemistry_score  biology_score  english_score  geography_score
# 0                  97             63             80               87
# 1                 100             90             88               90
# 2                  96             65             77               94
# 3                  80             89             63               86
# 4                  65             80             74               76
# ...               ...            ...            ...              ...
# 1995               73             75             84               82
# 1996               80             87             67               73
# 1997               93             68             94               78
# 1998               89             95             88               75
# 1999               69             83             93              100
#
# [2000 rows x 18 columns]

# %%
data["career_aspiration"].value_counts()
# Out:
# career_aspiration
# Software Engineer        315
# Business Owner           309
# Unknown                  223
# Banker                   169
# Lawyer                   138
# Accountant               126
# Doctor                   119
# Real Estate Developer     83
# Stock Investor            73
# Construction Engineer     68
# Artist                    67
# Game Developer            63
# Government Officer        61
# Teacher                   59
# Designer                  56
# Scientist                 39
# Writer                    32
# Name: count, dtype: int64

# %%
data["career_aspiration"].str.replace("Unknown","Software Engineer")
# Out:
# 0                      Lawyer
# 1                      Doctor
# 2          Government Officer
# 3                      Artist
# 4           Software Engineer
#                 ...
# 1995    Construction Engineer
# 1996        Software Engineer
# 1997        Software Engineer
# 1998           Business Owner
# 1999               Accountant
# Name: career_aspiration, Length: 2000, dtype: object

# %%
# math_score','history_score', 'physics_score', 'chemistry_score', 'biology_score','english_score', 'geography_score'
data["math_score"] + data["history_score"] + data["physics_score"] + data["chemistry_score"] + data["biology_score"] +data["english_score"] + data["geography_score"]
# Out:
# 0       574
# 1       640
# 2       605
# 3       551
# 4       521
#        ...
# 1995    558
# 1996    534
# 1997    578
# 1998    566
# 1999    617
# Length: 2000, dtype: int64

# %%
data
# Out:
#       index    id first_name last_name  \
# 0         0     1       Paul     Casey
# 1         1     2   Danielle  Sandoval
# 2         2     3       Tina   Andrews
# 3         3     4       Tara     Clark
# 4         4     5    Anthony    Campos
# ...     ...   ...        ...       ...
# 1995   1995  1996       Alan  Reynolds
# 1996   1996  1997     Thomas   Gilbert
# 1997   1997  1998    Madison     Cross
# 1998   1998  1999   Brittany   Compton
# 1999   1999  2000    Natalie     Smith
#
#                                         email  gender  part_time_job  \
# 0              paul.casey.1@gslingacademy.com    male              0
# 1       danielle.sandoval.2@gslingacademy.com  female              0
# 2            tina.andrews.3@gslingacademy.com  female              0
# 3              tara.clark.4@gslingacademy.com  female              0
# 4          anthony.campos.5@gslingacademy.com    male              0
# ...                                       ...     ...            ...
# 1995     alan.reynolds.1996@gslingacademy.com    male              0
# 1996    thomas.gilbert.1997@gslingacademy.com    male              0
# 1997     madison.cross.1998@gslingacademy.com  female              0
# 1998  brittany.compton.1999@gslingacademy.com  female              1
# 1999     natalie.smith.2000@gslingacademy.com  female              0
#
#       absence_days  extracurricular_activities  weekly_self_study_hours  \
# 0                3                           0                       27
# 1                2                           0                       47
# 2                9                           1                       13
# 3                5                           0                        3
# 4                5                           0                       10
# ...            ...                         ...                      ...
# 1995             2                           0                       30
# 1996             2                           0                       20
# 1997             5                           0                       14
# 1998            10                           1                        5
# 1999             5                           0                       27
#
#           career_aspiration  math_score  history_score  physics_score  \
# 0                    Lawyer          73             81             93
# 1                    Doctor          90             86             96
# 2        Government Officer          81             97             95
# 3                    Artist          71             74             88
# 4                   Unknown          84             77             65
# ...                     ...         ...            ...            ...
# 1995  Construction Engineer          83             77             84
# 1996      Software Engineer          89             65             73
# 1997      Software Engineer          97             85             63
# 1998         Business Owner          51             96             72
# 1999             Accountant          82             99             91
#
#       chemistry_score  biology_score  english_score  geography_score
# 0                  97             63             80               87
# 1                 100             90             88               90
# 2                  96             65             77               94
# 3                  80             89             63               86
# 4                  65             80             74               76
# ...               ...            ...            ...              ...
# 1995               73             75             84               82
# 1996               80             87             67               73
# 1997               93             68             94               78
# 1998               89             95             88               75
# 1999               69             83             93              100
#
# [2000 rows x 18 columns]

# %%
class DataTransformation:
    
    def __init__(self):
        pass
    def data_transformation(self,data):
        
        '''
        This method will take data as input and return transformed data
        
        arguments: data
        
        return: transformed data
        '''
        
        try:
            #drop index column from data
            data.drop(data.columns[0], axis=1,inplace=True)
            
            # replacr unknown feature with most frequent value Software Engineer
            data["career_aspiration"] = data["career_aspiration"].str.replace("Unknown","Software Engineer")
            
            # geting total score of each student
            data["total_score"] = data["math_score"] + data["history_score"] + data["physics_score"] + data["chemistry_score"] + data["biology_score"] +data["english_score"] + data["geography_score"]
            
            return data
        
        except Exception as e:
            print(e)
            
            
    def save_to_csv(self, data, file_name, path):
        
        '''
        arguments: data, file_name, path
        This method will save the data to csv file
        '''
        try:
            # create the folder if it does not exist
            if not os.path.exists(path):
                os.makedirs(path)

            # specify the full file path
            full_file_path = os.path.join(path, file_name)

            # ssave the data to a CSV file....
            data.to_csv(full_file_path, index=False)
            print(f"File '{file_name}' saved to disk in the '{path}' folder.")
        
        except Exception as e:
            print(e)

# %%
dt = DataTransformation()

# %%
transform_data = dt.data_transformation(data)

# %%
transform_data
# Out:
#         id first_name last_name                                    email  \
# 0        1       Paul     Casey           paul.casey.1@gslingacademy.com
# 1        2   Danielle  Sandoval    danielle.sandoval.2@gslingacademy.com
# 2        3       Tina   Andrews         tina.andrews.3@gslingacademy.com
# 3        4       Tara     Clark           tara.clark.4@gslingacademy.com
# 4        5    Anthony    Campos       anthony.campos.5@gslingacademy.com
# ...    ...        ...       ...                                      ...
# 1995  1996       Alan  Reynolds     alan.reynolds.1996@gslingacademy.com
# 1996  1997     Thomas   Gilbert    thomas.gilbert.1997@gslingacademy.com
# 1997  1998    Madison     Cross     madison.cross.1998@gslingacademy.com
# 1998  1999   Brittany   Compton  brittany.compton.1999@gslingacademy.com
# 1999  2000    Natalie     Smith     natalie.smith.2000@gslingacademy.com
#
#       gender  part_time_job  absence_days  extracurricular_activities  \
# 0       male              0             3                           0
# 1     female              0             2                           0
# 2     female              0             9                           1
# 3     female              0             5                           0
# 4       male              0             5                           0
# ...      ...            ...           ...                         ...
# 1995    male              0             2                           0
# 1996    male              0             2                           0
# 1997  female              0             5                           0
# 1998  female              1            10                           1
# 1999  female              0             5                           0
#
#       weekly_self_study_hours      career_aspiration  math_score  \
# 0                          27                 Lawyer          73
# 1                          47                 Doctor          90
# 2                          13     Government Officer          81
# 3                           3                 Artist          71
# 4                          10      Software Engineer          84
# ...                       ...                    ...         ...
# 1995                       30  Construction Engineer          83
# 1996                       20      Software Engineer          89
# 1997                       14      Software Engineer          97
# 1998                        5         Business Owner          51
# 1999                       27             Accountant          82
#
#       history_score  physics_score  chemistry_score  biology_score  \
# 0                81             93               97             63
# 1                86             96              100             90
# 2                97             95               96             65
# 3                74             88               80             89
# 4                77             65               65             80
# ...             ...            ...              ...            ...
# 1995             77             84               73             75
# 1996             65             73               80             87
# 1997             85             63               93             68
# 1998             96             72               89             95
# 1999             99             91               69             83
#
#       english_score  geography_score  total_score
# 0                80               87          574
# 1                88               90          640
# 2                77               94          605
# 3                63               86          551
# 4                74               76          521
# ...             ...              ...          ...
# 1995             84               82          558
# 1996             67               73          534
# 1997             94               78          578
# 1998             88               75          566
# 1999             93              100          617
#
# [2000 rows x 18 columns]

# %%
dt.save_to_csv(
    data = transform_data,
    file_name = "transform_student_data.csv",
    path = "data/")
# Out:
# File 'transform_student_data.csv' saved to disk in the 'data/' folder.

# %%
# def execute_query_to_dataframe(query, connection):
#     """
#     Executes a SQL query and returns the results as a pandas DataFrame.

#     Args:
#         query (str): SQL query to execute.
#         connection (pymysql.connections.Connection): Established database connection.

#     Returns:
#         pd.DataFrame: DataFrame containing the query results.
#     """
#     try:
#         df = pd.read_sql_query(query, connection)
#         return df

#     except Exception as e:
#         raise CustomException(f"Error executing query: {str(e)}")

# %%
class AWS_S3Manager:

    def __init__(self, bucket_name, aws_access_key_id, aws_secret_access_key, region_name):
        self.bucket_name = bucket_name
        self.s3_client = boto3.client(
            service_name='s3',
            region_name=region_name,
            aws_access_key_id=aws_access_key_id,
            aws_secret_access_key=aws_secret_access_key
        )

    def upload_file(self, local_filename, s3_key):
        
        '''
        arguments: local_filename, s3_key
        
        Upload file to S3_bucket 
        ''' 
        try:
            self.s3_client.upload_file(local_filename, self.bucket_name, s3_key)
            print(f"File '{local_filename}' uploaded to S3 bucket as '{s3_key}'.")

        except Exception as e:
            print(e)
        
        
    def download_file(self, s3_key, local_filename, target_directory="downloads"):
        
        '''
        arguments: local_filename, target_directory,s3_key
        
        Downloading the file to the target directory specified   in the S3_bucket configuration file and 
        rename the file to the local_filename specified in the S3_bucket configuration file.
        '''
        try:

            if not os.path.exists(target_directory):
                os.makedirs(target_directory)# create the target directory if it doesn't exist

            # Construct the full local path
            local_path = os.path.join(target_directory, local_filename)

            # Download the file
            self.s3_client.download_file(self.bucket_name, s3_key, local_path)
            print(f"File '{s3_key}' downloaded from S3 bucket and saved as '{local_path}'.")

        except Exception as e:
            print(e)

    def read_csv_from_s3(self, s3_key):
        
        '''
        arguments: s3_key
        
        Reads CSV file from S3 bucket.
        
        returns: data frame 
        '''
        try:
        
            obj = self.s3_client.get_object(Bucket=self.bucket_name, Key=s3_key)
            df = pd.read_csv(obj['Body'])
            return df
        
        except Exception as e:
            print(e)

# %%
aws = AWS_S3Manager(
    bucket_name = os.getenv("BUCKET_NAME"),
    aws_access_key_id = os.getenv("AWS_ACCESS_KEY_ID"),
    aws_secret_access_key = os.getenv("AWS_SECRET_ACCESS_KEY"),
    region_name = os.getenv("REGION_NAME")
)

# %%
aws.upload_file(
    local_filename = "data/transform_student_data.csv",
    s3_key = "transform_student_data.csv"
)
# Out:
# File 'data/transform_student_data.csv' uploaded to S3 bucket as 'transform_student_data.csv'.

# %%
data_s3 = aws.read_csv_from_s3(s3_key="transform_student_data.csv")

# %%
# convert in to tuple to insert in database 
data_s3 = list(data_s3.itertuples(index=False,name=None))

# %%
# create 2 table ym_transform_students_data in mysql data base 
sql_executer.execute_query("""
    CREATE TABLE IF NOT EXISTS ym_transform_students_data (
        id BIGINT NOT NULL,
        first_name VARCHAR(255) NOT NULL,
        last_name VARCHAR(255) NOT NULL,
        email VARCHAR(255) NOT NULL,
        gender VARCHAR(255) NOT NULL,
        part_time_job BIGINT NOT NULL,
        absence_days BIGINT NOT NULL,
        extracurricular_activities BIGINT NOT NULL,
        weekly_self_study_hours BIGINT NOT NULL,
        career_aspiration BIGINT NOT NULL,
        math_score BIGINT NOT NULL,
        history_score BIGINT NOT NULL,
        physics_score BIGINT NOT NULL,
        chemistry_score BIGINT NOT NULL,
        biology_score BIGINT NOT NULL,
        english_score BIGINT NOT NULL,
        geography_score BIGINT NOT NULL,
        total_score  BIGINT NOT NULL);
    """)
# Out:
# []

# %%
insert_qury = """
    INSERT INTO ym_transform_students_data (
        id,
        first_name,
        last_name,
        email,
        gender,
        part_time_job,
        absence_days,
        extracurricular_activities,
        weekly_self_study_hours,
        career_aspiration,
        math_score,
        history_score,
        physics_score,
        chemistry_score,
        biology_score,
        english_score,
        geography_score,
        total_score)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);
    """
    
sql_executer.insert_data_batch(
        insert_qury,
        data_s3,
        BATCH_SIZE= 200
    )

# %%
# Out:
# [(1,
#   'Paul',
#   'Casey',
#   'paul.casey.1@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   27,
#   'Lawyer',
#   73,
#   81,
#   93,
#   97,
#   63,
#   80,
#   87,
#   574),
#  (2,
#   'Danielle',
#   'Sandoval',
#   'danielle.sandoval.2@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   47,
#   'Doctor',
#   90,
#   86,
#   96,
#   100,
#   90,
#   88,
#   90,
#   640),
#  (3,
#   'Tina',
#   'Andrews',
#   'tina.andrews.3@gslingacademy.com',
#   'female',
#   0,
#   9,
#   1,
#   13,
#   'Government Officer',
#   81,
#   97,
#   95,
#   96,
#   65,
#   77,
#   94,
#   605),
#  (4,
#   'Tara',
#   'Clark',
#   'tara.clark.4@gslingacademy.com',
#   'female',
#   0,
#   5,
#   0,
#   3,
#   'Artist',
#   71,
#   74,
#   88,
#   80,
#   89,
#   63,
#   86,
#   551),
#  (5,
#   'Anthony',
#   'Campos',
#   'anthony.campos.5@gslingacademy.com',
#   'male',
#   0,
#   5,
#   0,
#   10,
#   'Software Engineer',
#   84,
#   77,
#   65,
#   65,
#   80,
#   74,
#   76,
#   521),
#  (6,
#   'Kelly',
#   'Wade',
#   'kelly.wade.6@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   26,
#   'Software Engineer',
#   93,
#   100,
#   67,
#   78,
#   72,
#   80,
#   84,
#   574),
#  (7,
#   'Anthony',
#   'Smith',
#   'anthony.smith.7@gslingacademy.com',
#   'male',
#   0,
#   3,
#   1,
#   23,
#   'Software Engineer',
#   99,
#   96,
#   97,
#   73,
#   88,
#   76,
#   64,
#   593),
#  (8,
#   'George',
#   'Short',
#   'george.short.8@gslingacademy.com',
#   'male',
#   1,
#   2,
#   1,
#   34,
#   'Software Engineer',
#   95,
#   95,
#   82,
#   63,
#   84,
#   70,
#   85,
#   574),
#  (9,
#   'Stanley',
#   'Gutierrez',
#   'stanley.gutierrez.9@gslingacademy.com',
#   'male',
#   0,
#   6,
#   0,
#   25,
#   'Software Engineer',
#   94,
#   68,
#   94,
#   85,
#   81,
#   74,
#   72,
#   568),
#  (10,
#   'Audrey',
#   'Simpson',
#   'audrey.simpson.10@gslingacademy.com',
#   'female',
#   0,
#   3,
#   1,
#   18,
#   'Teacher',
#   98,
#   69,
#   88,
#   71,
#   67,
#   71,
#   73,
#   537),
#  (11,
#   'Gabrielle',
#   'White',
#   'gabrielle.white.11@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   7,
#   'Teacher',
#   65,
#   60,
#   97,
#   94,
#   71,
#   81,
#   66,
#   534),
#  (12,
#   'Clinton',
#   'Randolph',
#   'clinton.randolph.12@gslingacademy.com',
#   'male',
#   0,
#   1,
#   0,
#   7,
#   'Software Engineer',
#   80,
#   61,
#   100,
#   65,
#   87,
#   64,
#   61,
#   518),
#  (13,
#   'Patricia',
#   'Gomez',
#   'patricia.gomez.13@gslingacademy.com',
#   'female',
#   1,
#   7,
#   0,
#   4,
#   'Business Owner',
#   94,
#   59,
#   69,
#   67,
#   89,
#   65,
#   73,
#   516),
#  (14,
#   'Pamela',
#   'Jackson',
#   'pamela.jackson.14@gslingacademy.com',
#   'female',
#   0,
#   10,
#   0,
#   2,
#   'Business Owner',
#   66,
#   94,
#   86,
#   100,
#   57,
#   90,
#   63,
#   556),
#  (15,
#   'Laura',
#   'Jackson',
#   'laura.jackson.15@gslingacademy.com',
#   'female',
#   0,
#   3,
#   0,
#   39,
#   'Doctor',
#   96,
#   90,
#   86,
#   92,
#   92,
#   95,
#   87,
#   638),
#  (16,
#   'Roger',
#   'Wiley',
#   'roger.wiley.16@gslingacademy.com',
#   'male',
#   0,
#   6,
#   0,
#   0,
#   'Business Owner',
#   94,
#   50,
#   78,
#   64,
#   79,
#   74,
#   84,
#   523),
#  (17,
#   'Vicki',
#   'Thompson',
#   'vicki.thompson.17@gslingacademy.com',
#   'female',
#   0,
#   3,
#   1,
#   30,
#   'Scientist',
#   92,
#   64,
#   93,
#   91,
#   80,
#   89,
#   72,
#   581),
#  (18,
#   'Maxwell',
#   'Davidson',
#   'maxwell.davidson.18@gslingacademy.com',
#   'male',
#   0,
#   2,
#   1,
#   28,
#   'Software Engineer',
#   86,
#   83,
#   85,
#   79,
#   93,
#   76,
#   77,
#   579),
#  (19,
#   'Jonathan',
#   'Werner',
#   'jonathan.werner.19@gslingacademy.com',
#   'male',
#   0,
#   1,
#   0,
#   37,
#   'Doctor',
#   92,
#   87,
#   92,
#   99,
#   97,
#   87,
#   86,
#   640),
#  (20,
#   'Angela',
#   'Rios',
#   'angela.rios.20@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   27,
#   'Software Engineer',
#   99,
#   65,
#   98,
#   75,
#   66,
#   72,
#   100,
#   575),
#  (21,
#   'Tim',
#   'Nichols',
#   'tim.nichols.21@gslingacademy.com',
#   'male',
#   1,
#   3,
#   0,
#   15,
#   'Software Engineer',
#   100,
#   90,
#   72,
#   98,
#   73,
#   97,
#   72,
#   602),
#  (22,
#   'Kyle',
#   'Willis',
#   'kyle.willis.22@gslingacademy.com',
#   'male',
#   0,
#   8,
#   0,
#   4,
#   'Business Owner',
#   57,
#   55,
#   78,
#   94,
#   83,
#   88,
#   88,
#   543),
#  (23,
#   'Shannon',
#   'Simpson',
#   'shannon.simpson.23@gslingacademy.com',
#   'female',
#   0,
#   9,
#   0,
#   2,
#   'Business Owner',
#   89,
#   72,
#   68,
#   72,
#   71,
#   54,
#   90,
#   516),
#  (24,
#   'Sean',
#   'Griffin',
#   'sean.griffin.24@gslingacademy.com',
#   'male',
#   0,
#   9,
#   0,
#   1,
#   'Business Owner',
#   50,
#   76,
#   81,
#   55,
#   56,
#   80,
#   79,
#   477),
#  (25,
#   'Cassandra',
#   'West',
#   'cassandra.west.25@gslingacademy.com',
#   'female',
#   0,
#   4,
#   0,
#   35,
#   'Software Engineer',
#   87,
#   91,
#   90,
#   88,
#   95,
#   88,
#   93,
#   632),
#  (26,
#   'Patricia',
#   'Chavez',
#   'patricia.chavez.26@gslingacademy.com',
#   'female',
#   0,
#   5,
#   0,
#   22,
#   'Doctor',
#   92,
#   86,
#   87,
#   81,
#   93,
#   90,
#   99,
#   628),
#  (27,
#   'Jason',
#   'Williams',
#   'jason.williams.27@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   34,
#   'Banker',
#   100,
#   77,
#   80,
#   94,
#   63,
#   90,
#   90,
#   594),
#  (28,
#   'Peter',
#   'Gibbs',
#   'peter.gibbs.28@gslingacademy.com',
#   'male',
#   0,
#   0,
#   0,
#   23,
#   'Writer',
#   64,
#   75,
#   93,
#   79,
#   81,
#   96,
#   85,
#   573),
#  (29,
#   'Jeffrey',
#   'Blanchard',
#   'jeffrey.blanchard.29@gslingacademy.com',
#   'male',
#   0,
#   1,
#   1,
#   17,
#   'Accountant',
#   79,
#   65,
#   99,
#   71,
#   76,
#   77,
#   83,
#   550),
#  (30,
#   'Carol',
#   'Hill',
#   'carol.hill.30@gslingacademy.com',
#   'female',
#   0,
#   3,
#   0,
#   19,
#   'Accountant',
#   82,
#   100,
#   61,
#   97,
#   30,
#   74,
#   73,
#   517),
#  (31,
#   'Angie',
#   'Miller',
#   'angie.miller.31@gslingacademy.com',
#   'female',
#   0,
#   0,
#   0,
#   14,
#   'Software Engineer',
#   88,
#   69,
#   87,
#   100,
#   88,
#   85,
#   72,
#   589),
#  (32,
#   'Cynthia',
#   'Knapp',
#   'cynthia.knapp.32@gslingacademy.com',
#   'female',
#   0,
#   4,
#   0,
#   30,
#   'Designer',
#   70,
#   68,
#   92,
#   74,
#   82,
#   85,
#   72,
#   543),
#  (33,
#   'Timothy',
#   'Bryant',
#   'timothy.bryant.33@gslingacademy.com',
#   'male',
#   0,
#   4,
#   0,
#   30,
#   'Accountant',
#   77,
#   96,
#   98,
#   89,
#   85,
#   62,
#   62,
#   569),
#  (34,
#   'Phyllis',
#   'Diaz',
#   'phyllis.diaz.34@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   24,
#   'Banker',
#   99,
#   84,
#   84,
#   78,
#   78,
#   77,
#   68,
#   568),
#  (35,
#   'Lisa',
#   'Burns',
#   'lisa.burns.35@gslingacademy.com',
#   'female',
#   0,
#   3,
#   1,
#   31,
#   'Software Engineer',
#   90,
#   93,
#   91,
#   80,
#   86,
#   69,
#   62,
#   571),
#  (36,
#   'Kelly',
#   'Farley',
#   'kelly.farley.36@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   21,
#   'Software Engineer',
#   65,
#   70,
#   78,
#   98,
#   80,
#   66,
#   65,
#   522),
#  (37,
#   'Ryan',
#   'Lee',
#   'ryan.lee.37@gslingacademy.com',
#   'male',
#   0,
#   2,
#   1,
#   19,
#   'Construction Engineer',
#   99,
#   94,
#   87,
#   71,
#   89,
#   91,
#   96,
#   627),
#  (38,
#   'Michael',
#   'Gilmore',
#   'michael.gilmore.38@gslingacademy.com',
#   'male',
#   0,
#   1,
#   0,
#   29,
#   'Construction Engineer',
#   92,
#   100,
#   85,
#   89,
#   81,
#   91,
#   88,
#   626),
#  (39,
#   'Miguel',
#   'Martinez',
#   'miguel.martinez.39@gslingacademy.com',
#   'male',
#   0,
#   4,
#   0,
#   21,
#   'Banker',
#   77,
#   64,
#   64,
#   88,
#   94,
#   82,
#   78,
#   547),
#  (40,
#   'Christopher',
#   'Taylor',
#   'christopher.taylor.40@gslingacademy.com',
#   'male',
#   0,
#   4,
#   0,
#   18,
#   'Accountant',
#   92,
#   60,
#   66,
#   87,
#   60,
#   83,
#   95,
#   543),
#  (41,
#   'Emily',
#   'Holloway',
#   'emily.holloway.41@gslingacademy.com',
#   'female',
#   0,
#   4,
#   0,
#   31,
#   'Software Engineer',
#   85,
#   97,
#   64,
#   90,
#   79,
#   81,
#   81,
#   577),
#  (42,
#   'Jesus',
#   'Rasmussen',
#   'jesus.rasmussen.42@gslingacademy.com',
#   'male',
#   1,
#   7,
#   0,
#   4,
#   'Business Owner',
#   65,
#   55,
#   66,
#   50,
#   88,
#   56,
#   86,
#   466),
#  (43,
#   'Lauren',
#   'Farmer',
#   'lauren.farmer.43@gslingacademy.com',
#   'female',
#   1,
#   6,
#   0,
#   3,
#   'Business Owner',
#   93,
#   94,
#   92,
#   77,
#   87,
#   98,
#   63,
#   604),
#  (44,
#   'Pamela',
#   'Cole',
#   'pamela.cole.44@gslingacademy.com',
#   'female',
#   0,
#   4,
#   0,
#   3,
#   'Game Developer',
#   97,
#   99,
#   85,
#   96,
#   91,
#   68,
#   66,
#   602),
#  (45,
#   'David',
#   'Gillespie',
#   'david.gillespie.45@gslingacademy.com',
#   'male',
#   1,
#   4,
#   0,
#   3,
#   'Business Owner',
#   54,
#   99,
#   79,
#   57,
#   53,
#   95,
#   83,
#   520),
#  (46,
#   'Kenneth',
#   'Davis',
#   'kenneth.davis.46@gslingacademy.com',
#   'male',
#   1,
#   5,
#   1,
#   5,
#   'Business Owner',
#   88,
#   53,
#   50,
#   58,
#   84,
#   53,
#   96,
#   482),
#  (47,
#   'Elizabeth',
#   'Martin',
#   'elizabeth.martin.47@gslingacademy.com',
#   'female',
#   0,
#   5,
#   1,
#   27,
#   'Lawyer',
#   71,
#   85,
#   93,
#   68,
#   100,
#   91,
#   87,
#   595),
#  (48,
#   'Billy',
#   'Soto',
#   'billy.soto.48@gslingacademy.com',
#   'male',
#   0,
#   0,
#   1,
#   28,
#   'Stock Investor',
#   81,
#   98,
#   74,
#   70,
#   97,
#   65,
#   65,
#   550),
#  (49,
#   'Kimberly',
#   'Kelly',
#   'kimberly.kelly.49@gslingacademy.com',
#   'female',
#   0,
#   4,
#   0,
#   32,
#   'Software Engineer',
#   80,
#   78,
#   86,
#   80,
#   64,
#   68,
#   100,
#   556),
#  (50,
#   'Sonia',
#   'Noble',
#   'sonia.noble.50@gslingacademy.com',
#   'female',
#   0,
#   0,
#   0,
#   14,
#   'Accountant',
#   100,
#   89,
#   90,
#   93,
#   30,
#   83,
#   74,
#   559),
#  (51,
#   'Christopher',
#   'Stewart',
#   'christopher.stewart.51@gslingacademy.com',
#   'male',
#   0,
#   6,
#   1,
#   16,
#   'Stock Investor',
#   76,
#   72,
#   96,
#   65,
#   89,
#   87,
#   94,
#   579),
#  (52,
#   'Sandra',
#   'Thornton',
#   'sandra.thornton.52@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   24,
#   'Lawyer',
#   99,
#   81,
#   73,
#   70,
#   85,
#   86,
#   61,
#   555),
#  (53,
#   'Luke',
#   'Shannon',
#   'luke.shannon.53@gslingacademy.com',
#   'male',
#   0,
#   9,
#   0,
#   0,
#   'Business Owner',
#   64,
#   70,
#   61,
#   81,
#   82,
#   51,
#   70,
#   479),
#  (54,
#   'Lindsay',
#   'Pruitt',
#   'lindsay.pruitt.54@gslingacademy.com',
#   'female',
#   0,
#   3,
#   0,
#   32,
#   'Banker',
#   90,
#   96,
#   86,
#   61,
#   89,
#   98,
#   68,
#   588),
#  (55,
#   'Jamie',
#   'Taylor',
#   'jamie.taylor.55@gslingacademy.com',
#   'male',
#   0,
#   2,
#   0,
#   3,
#   'Game Developer',
#   85,
#   100,
#   92,
#   68,
#   60,
#   77,
#   83,
#   565),
#  (56,
#   'Jennifer',
#   'Murphy',
#   'jennifer.murphy.56@gslingacademy.com',
#   'female',
#   0,
#   6,
#   0,
#   31,
#   'Software Engineer',
#   91,
#   60,
#   84,
#   88,
#   76,
#   71,
#   99,
#   569),
#  (57,
#   'Melissa',
#   'Lee',
#   'melissa.lee.57@gslingacademy.com',
#   'female',
#   0,
#   3,
#   0,
#   21,
#   'Software Engineer',
#   95,
#   72,
#   79,
#   86,
#   87,
#   81,
#   62,
#   562),
#  (58,
#   'David',
#   'Vaughn',
#   'david.vaughn.58@gslingacademy.com',
#   'male',
#   1,
#   2,
#   0,
#   18,
#   'Banker',
#   94,
#   78,
#   73,
#   97,
#   67,
#   78,
#   99,
#   586),
#  (59,
#   'Jacob',
#   'Hanson',
#   'jacob.hanson.59@gslingacademy.com',
#   'male',
#   0,
#   7,
#   0,
#   26,
#   'Software Engineer',
#   94,
#   89,
#   64,
#   96,
#   91,
#   95,
#   77,
#   606),
#  (60,
#   'Casey',
#   'May',
#   'casey.may.60@gslingacademy.com',
#   'male',
#   0,
#   4,
#   0,
#   23,
#   'Software Engineer',
#   89,
#   99,
#   90,
#   79,
#   85,
#   96,
#   98,
#   636),
#  (61,
#   'Michelle',
#   'Roman',
#   'michelle.roman.61@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   1,
#   'Game Developer',
#   91,
#   81,
#   88,
#   71,
#   78,
#   83,
#   76,
#   568),
#  (62,
#   'Brittany',
#   'Koch',
#   'brittany.koch.62@gslingacademy.com',
#   'female',
#   0,
#   5,
#   0,
#   33,
#   'Lawyer',
#   83,
#   86,
#   61,
#   99,
#   99,
#   88,
#   73,
#   589),
#  (63,
#   'Brian',
#   'Lewis',
#   'brian.lewis.63@gslingacademy.com',
#   'male',
#   0,
#   7,
#   0,
#   2,
#   'Business Owner',
#   98,
#   65,
#   53,
#   64,
#   52,
#   96,
#   62,
#   490),
#  (64,
#   'Veronica',
#   'Cameron',
#   'veronica.cameron.64@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   34,
#   'Banker',
#   83,
#   97,
#   65,
#   88,
#   67,
#   95,
#   69,
#   564),
#  (65,
#   'Eric',
#   'Reyes',
#   'eric.reyes.65@gslingacademy.com',
#   'male',
#   0,
#   2,
#   0,
#   18,
#   'Construction Engineer',
#   91,
#   73,
#   99,
#   70,
#   63,
#   80,
#   78,
#   554),
#  (66,
#   'Kristy',
#   'Weber',
#   'kristy.weber.66@gslingacademy.com',
#   'female',
#   1,
#   6,
#   0,
#   2,
#   'Business Owner',
#   90,
#   54,
#   77,
#   74,
#   76,
#   96,
#   88,
#   555),
#  (67,
#   'Anthony',
#   'Smith',
#   'anthony.smith.67@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   27,
#   'Software Engineer',
#   92,
#   86,
#   66,
#   69,
#   100,
#   71,
#   80,
#   564),
#  (68,
#   'Steven',
#   'Stephens',
#   'steven.stephens.68@gslingacademy.com',
#   'male',
#   0,
#   2,
#   0,
#   8,
#   'Real Estate Developer',
#   64,
#   64,
#   73,
#   76,
#   72,
#   97,
#   91,
#   537),
#  (69,
#   'Henry',
#   'Davis',
#   'henry.davis.69@gslingacademy.com',
#   'male',
#   0,
#   4,
#   0,
#   14,
#   'Software Engineer',
#   90,
#   70,
#   85,
#   60,
#   81,
#   71,
#   88,
#   545),
#  (70,
#   'Raymond',
#   'Shea',
#   'raymond.shea.70@gslingacademy.com',
#   'male',
#   0,
#   10,
#   1,
#   22,
#   'Banker',
#   99,
#   81,
#   96,
#   69,
#   91,
#   87,
#   83,
#   606),
#  (71,
#   'Jill',
#   'Perez',
#   'jill.perez.71@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   15,
#   'Designer',
#   89,
#   66,
#   93,
#   81,
#   86,
#   88,
#   70,
#   573),
#  (72,
#   'Kimberly',
#   'Bonilla',
#   'kimberly.bonilla.72@gslingacademy.com',
#   'female',
#   1,
#   3,
#   0,
#   22,
#   'Writer',
#   62,
#   87,
#   93,
#   83,
#   93,
#   97,
#   73,
#   588),
#  (73,
#   'Louis',
#   'Edwards',
#   'louis.edwards.73@gslingacademy.com',
#   'male',
#   1,
#   10,
#   0,
#   1,
#   'Business Owner',
#   61,
#   70,
#   69,
#   64,
#   59,
#   78,
#   80,
#   481),
#  (74,
#   'Michael',
#   'Hodge',
#   'michael.hodge.74@gslingacademy.com',
#   'male',
#   1,
#   8,
#   0,
#   3,
#   'Business Owner',
#   51,
#   54,
#   66,
#   87,
#   99,
#   58,
#   68,
#   483),
#  (75,
#   'Anna',
#   'Li',
#   'anna.li.75@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   20,
#   'Software Engineer',
#   85,
#   100,
#   64,
#   68,
#   73,
#   81,
#   87,
#   558),
#  (76,
#   'Andrea',
#   'Case',
#   'andrea.case.76@gslingacademy.com',
#   'female',
#   0,
#   7,
#   1,
#   27,
#   'Software Engineer',
#   99,
#   90,
#   96,
#   92,
#   100,
#   98,
#   77,
#   652),
#  (77,
#   'Jennifer',
#   'Garcia',
#   'jennifer.garcia.77@gslingacademy.com',
#   'female',
#   0,
#   3,
#   0,
#   24,
#   'Software Engineer',
#   87,
#   63,
#   60,
#   90,
#   89,
#   99,
#   80,
#   568),
#  (78,
#   'Rhonda',
#   'Davenport',
#   'rhonda.davenport.78@gslingacademy.com',
#   'female',
#   0,
#   1,
#   1,
#   5,
#   'Software Engineer',
#   75,
#   91,
#   80,
#   93,
#   74,
#   93,
#   65,
#   571),
#  (79,
#   'Chelsea',
#   'Craig',
#   'chelsea.craig.79@gslingacademy.com',
#   'female',
#   0,
#   7,
#   0,
#   34,
#   'Software Engineer',
#   88,
#   94,
#   80,
#   63,
#   68,
#   77,
#   64,
#   534),
#  (80,
#   'Shawn',
#   'Chase',
#   'shawn.chase.80@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   16,
#   'Software Engineer',
#   87,
#   79,
#   89,
#   68,
#   93,
#   75,
#   92,
#   583),
#  (81,
#   'Elizabeth',
#   'Calhoun',
#   'elizabeth.calhoun.81@gslingacademy.com',
#   'female',
#   1,
#   3,
#   0,
#   3,
#   'Business Owner',
#   87,
#   67,
#   94,
#   92,
#   62,
#   58,
#   65,
#   525),
#  (82,
#   'Lisa',
#   'Harris',
#   'lisa.harris.82@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   15,
#   'Stock Investor',
#   76,
#   67,
#   83,
#   85,
#   91,
#   61,
#   67,
#   530),
#  (83,
#   'Carol',
#   'Snyder',
#   'carol.snyder.83@gslingacademy.com',
#   'female',
#   0,
#   7,
#   0,
#   11,
#   'Government Officer',
#   60,
#   80,
#   61,
#   63,
#   95,
#   92,
#   75,
#   526),
#  (84,
#   'Charles',
#   'Butler',
#   'charles.butler.84@gslingacademy.com',
#   'male',
#   0,
#   7,
#   0,
#   32,
#   'Scientist',
#   85,
#   65,
#   99,
#   100,
#   88,
#   93,
#   72,
#   602),
#  (85,
#   'James',
#   'Dawson',
#   'james.dawson.85@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   28,
#   'Software Engineer',
#   73,
#   67,
#   70,
#   71,
#   65,
#   73,
#   87,
#   506),
#  (86,
#   'Dennis',
#   'Kim',
#   'dennis.kim.86@gslingacademy.com',
#   'male',
#   0,
#   1,
#   0,
#   24,
#   'Software Engineer',
#   85,
#   71,
#   69,
#   80,
#   70,
#   77,
#   66,
#   518),
#  (87,
#   'Jennifer',
#   'Berry',
#   'jennifer.berry.87@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   9,
#   'Government Officer',
#   91,
#   76,
#   71,
#   72,
#   92,
#   67,
#   90,
#   559),
#  (88,
#   'Yvette',
#   'Bridges',
#   'yvette.bridges.88@gslingacademy.com',
#   'female',
#   0,
#   3,
#   1,
#   14,
#   'Software Engineer',
#   99,
#   95,
#   83,
#   89,
#   81,
#   63,
#   70,
#   580),
#  (89,
#   'Robert',
#   'Atkins',
#   'robert.atkins.89@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   16,
#   'Stock Investor',
#   93,
#   96,
#   68,
#   87,
#   69,
#   89,
#   100,
#   602),
#  (90,
#   'William',
#   'Brown',
#   'william.brown.90@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   29,
#   'Software Engineer',
#   89,
#   75,
#   60,
#   80,
#   62,
#   85,
#   73,
#   524),
#  (91,
#   'Patrick',
#   'Parker',
#   'patrick.parker.91@gslingacademy.com',
#   'male',
#   0,
#   0,
#   0,
#   14,
#   'Accountant',
#   95,
#   78,
#   95,
#   73,
#   32,
#   65,
#   68,
#   506),
#  (92,
#   'James',
#   'Santiago',
#   'james.santiago.92@gslingacademy.com',
#   'male',
#   0,
#   4,
#   0,
#   10,
#   'Government Officer',
#   68,
#   82,
#   95,
#   63,
#   62,
#   98,
#   93,
#   561),
#  (93,
#   'Robert',
#   'Parsons',
#   'robert.parsons.93@gslingacademy.com',
#   'male',
#   0,
#   5,
#   0,
#   31,
#   'Software Engineer',
#   98,
#   73,
#   73,
#   77,
#   87,
#   98,
#   83,
#   589),
#  (94,
#   'Jacob',
#   'Brown',
#   'jacob.brown.94@gslingacademy.com',
#   'male',
#   0,
#   4,
#   0,
#   34,
#   'Stock Investor',
#   79,
#   92,
#   79,
#   76,
#   84,
#   67,
#   86,
#   563),
#  (95,
#   'Natalie',
#   'Robinson',
#   'natalie.robinson.95@gslingacademy.com',
#   'female',
#   0,
#   5,
#   0,
#   3,
#   'Software Engineer',
#   78,
#   79,
#   73,
#   96,
#   64,
#   93,
#   85,
#   568),
#  (96,
#   'Victoria',
#   'Jones',
#   'victoria.jones.96@gslingacademy.com',
#   'female',
#   0,
#   2,
#   1,
#   34,
#   'Software Engineer',
#   100,
#   98,
#   89,
#   85,
#   81,
#   64,
#   94,
#   611),
#  (97,
#   'Natasha',
#   'Hansen',
#   'natasha.hansen.97@gslingacademy.com',
#   'female',
#   0,
#   3,
#   1,
#   2,
#   'Artist',
#   86,
#   76,
#   84,
#   93,
#   76,
#   69,
#   91,
#   575),
#  (98,
#   'Thomas',
#   'White',
#   'thomas.white.98@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   4,
#   'Real Estate Developer',
#   87,
#   89,
#   93,
#   98,
#   79,
#   72,
#   88,
#   606),
#  (99,
#   'Derrick',
#   'Figueroa',
#   'derrick.figueroa.99@gslingacademy.com',
#   'male',
#   1,
#   0,
#   0,
#   28,
#   'Lawyer',
#   100,
#   93,
#   85,
#   61,
#   96,
#   83,
#   86,
#   604),
#  (100,
#   'Kimberly',
#   'Ward',
#   'kimberly.ward.100@gslingacademy.com',
#   'female',
#   0,
#   0,
#   0,
#   5,
#   'Game Developer',
#   85,
#   89,
#   94,
#   69,
#   99,
#   93,
#   98,
#   627),
#  (101,
#   'Rhonda',
#   'Jones',
#   'rhonda.jones.101@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   4,
#   'Artist',
#   87,
#   73,
#   98,
#   91,
#   79,
#   60,
#   77,
#   565),
#  (102,
#   'Abigail',
#   'Perez',
#   'abigail.perez.102@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   25,
#   'Software Engineer',
#   96,
#   80,
#   100,
#   61,
#   81,
#   98,
#   65,
#   581),
#  (103,
#   'James',
#   'Yang',
#   'james.yang.103@gslingacademy.com',
#   'male',
#   0,
#   5,
#   0,
#   29,
#   'Writer',
#   76,
#   87,
#   64,
#   74,
#   73,
#   90,
#   99,
#   563),
#  (104,
#   'Stephen',
#   'Patton',
#   'stephen.patton.104@gslingacademy.com',
#   'male',
#   1,
#   6,
#   0,
#   1,
#   'Artist',
#   90,
#   80,
#   63,
#   94,
#   64,
#   70,
#   79,
#   540),
#  (105,
#   'Emma',
#   'Wright',
#   'emma.wright.105@gslingacademy.com',
#   'female',
#   0,
#   7,
#   0,
#   2,
#   'Business Owner',
#   65,
#   60,
#   100,
#   91,
#   87,
#   78,
#   99,
#   580),
#  (106,
#   'Cynthia',
#   'Brown',
#   'cynthia.brown.106@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   0,
#   'Real Estate Developer',
#   98,
#   97,
#   62,
#   89,
#   62,
#   95,
#   77,
#   580),
#  (107,
#   'Erin',
#   'Kelley',
#   'erin.kelley.107@gslingacademy.com',
#   'female',
#   0,
#   3,
#   0,
#   16,
#   'Accountant',
#   91,
#   80,
#   97,
#   89,
#   94,
#   95,
#   84,
#   630),
#  (108,
#   'Benjamin',
#   'Morse',
#   'benjamin.morse.108@gslingacademy.com',
#   'male',
#   0,
#   3,
#   1,
#   31,
#   'Scientist',
#   86,
#   81,
#   83,
#   81,
#   81,
#   77,
#   86,
#   575),
#  (109,
#   'Alexandra',
#   'Gibson',
#   'alexandra.gibson.109@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   4,
#   'Software Engineer',
#   91,
#   93,
#   72,
#   61,
#   61,
#   87,
#   95,
#   560),
#  (110,
#   'Phillip',
#   'Allen',
#   'phillip.allen.110@gslingacademy.com',
#   'male',
#   0,
#   5,
#   1,
#   13,
#   'Accountant',
#   78,
#   69,
#   82,
#   60,
#   64,
#   77,
#   82,
#   512),
#  (111,
#   'Joshua',
#   'Gonzalez',
#   'joshua.gonzalez.111@gslingacademy.com',
#   'male',
#   0,
#   4,
#   0,
#   24,
#   'Stock Investor',
#   76,
#   89,
#   89,
#   83,
#   89,
#   90,
#   64,
#   580),
#  (112,
#   'Erin',
#   'Jones',
#   'erin.jones.112@gslingacademy.com',
#   'female',
#   1,
#   9,
#   0,
#   2,
#   'Business Owner',
#   82,
#   54,
#   85,
#   57,
#   50,
#   54,
#   76,
#   458),
#  (113,
#   'Charles',
#   'Hayes',
#   'charles.hayes.113@gslingacademy.com',
#   'male',
#   1,
#   2,
#   1,
#   4,
#   'Business Owner',
#   45,
#   85,
#   94,
#   76,
#   57,
#   93,
#   86,
#   536),
#  (114,
#   'Kelsey',
#   'Brown',
#   'kelsey.brown.114@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   22,
#   'Banker',
#   92,
#   75,
#   65,
#   97,
#   61,
#   76,
#   81,
#   547),
#  (115,
#   'Robert',
#   'Turner',
#   'robert.turner.115@gslingacademy.com',
#   'male',
#   0,
#   6,
#   1,
#   0,
#   'Business Owner',
#   43,
#   65,
#   91,
#   75,
#   64,
#   94,
#   100,
#   532),
#  (116,
#   'Robert',
#   'Hill',
#   'robert.hill.116@gslingacademy.com',
#   'male',
#   0,
#   2,
#   0,
#   24,
#   'Software Engineer',
#   96,
#   66,
#   69,
#   65,
#   72,
#   84,
#   77,
#   529),
#  (117,
#   'Alyssa',
#   'Ritter',
#   'alyssa.ritter.117@gslingacademy.com',
#   'female',
#   0,
#   6,
#   0,
#   1,
#   'Business Owner',
#   78,
#   71,
#   50,
#   55,
#   54,
#   97,
#   95,
#   500),
#  (118,
#   'Beth',
#   'Bell',
#   'beth.bell.118@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   19,
#   'Software Engineer',
#   68,
#   96,
#   64,
#   70,
#   74,
#   63,
#   75,
#   510),
#  (119,
#   'Andrew',
#   'Dixon',
#   'andrew.dixon.119@gslingacademy.com',
#   'male',
#   0,
#   1,
#   1,
#   19,
#   'Software Engineer',
#   93,
#   73,
#   94,
#   65,
#   60,
#   63,
#   93,
#   541),
#  (120,
#   'Crystal',
#   'Walker',
#   'crystal.walker.120@gslingacademy.com',
#   'female',
#   0,
#   6,
#   0,
#   5,
#   'Business Owner',
#   55,
#   93,
#   67,
#   74,
#   55,
#   60,
#   64,
#   468),
#  (121,
#   'Jordan',
#   'Bennett',
#   'jordan.bennett.121@gslingacademy.com',
#   'female',
#   1,
#   0,
#   0,
#   13,
#   'Teacher',
#   66,
#   90,
#   83,
#   80,
#   76,
#   90,
#   91,
#   576),
#  (122,
#   'Antonio',
#   'Caldwell',
#   'antonio.caldwell.122@gslingacademy.com',
#   'male',
#   0,
#   4,
#   0,
#   26,
#   'Doctor',
#   98,
#   92,
#   91,
#   99,
#   97,
#   88,
#   75,
#   640),
#  (123,
#   'Jacob',
#   'Reyes',
#   'jacob.reyes.123@gslingacademy.com',
#   'male',
#   0,
#   4,
#   0,
#   41,
#   'Doctor',
#   94,
#   94,
#   94,
#   89,
#   85,
#   86,
#   85,
#   627),
#  (124,
#   'Wendy',
#   'Lewis',
#   'wendy.lewis.124@gslingacademy.com',
#   'female',
#   0,
#   3,
#   0,
#   47,
#   'Doctor',
#   96,
#   100,
#   96,
#   91,
#   91,
#   96,
#   89,
#   659),
#  (125,
#   'Jennifer',
#   'Miller',
#   'jennifer.miller.125@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   9,
#   'Software Engineer',
#   69,
#   62,
#   82,
#   89,
#   81,
#   72,
#   71,
#   526),
#  (126,
#   'Lisa',
#   'Ware',
#   'lisa.ware.126@gslingacademy.com',
#   'female',
#   0,
#   4,
#   0,
#   7,
#   'Software Engineer',
#   77,
#   95,
#   98,
#   69,
#   60,
#   89,
#   71,
#   559),
#  (127,
#   'Brian',
#   'Lee',
#   'brian.lee.127@gslingacademy.com',
#   'male',
#   0,
#   1,
#   0,
#   3,
#   'Game Developer',
#   89,
#   67,
#   86,
#   87,
#   87,
#   68,
#   78,
#   562),
#  (128,
#   'Mario',
#   'Taylor',
#   'mario.taylor.128@gslingacademy.com',
#   'male',
#   0,
#   4,
#   1,
#   14,
#   'Accountant',
#   96,
#   67,
#   80,
#   83,
#   86,
#   77,
#   75,
#   564),
#  (129,
#   'Amanda',
#   'Williamson',
#   'amanda.williamson.129@gslingacademy.com',
#   'female',
#   0,
#   4,
#   0,
#   26,
#   'Software Engineer',
#   82,
#   70,
#   80,
#   70,
#   96,
#   69,
#   86,
#   553),
#  (130,
#   'Michael',
#   'Miller',
#   'michael.miller.130@gslingacademy.com',
#   'male',
#   0,
#   6,
#   1,
#   27,
#   'Software Engineer',
#   99,
#   97,
#   64,
#   90,
#   87,
#   68,
#   69,
#   574),
#  (131,
#   'Amanda',
#   'Vasquez',
#   'amanda.vasquez.131@gslingacademy.com',
#   'female',
#   1,
#   5,
#   0,
#   25,
#   'Stock Investor',
#   96,
#   73,
#   90,
#   85,
#   63,
#   84,
#   87,
#   578),
#  (132,
#   'Chelsea',
#   'Obrien',
#   'chelsea.obrien.132@gslingacademy.com',
#   'female',
#   1,
#   4,
#   0,
#   16,
#   'Banker',
#   95,
#   82,
#   66,
#   63,
#   67,
#   92,
#   69,
#   534),
#  (133,
#   'Tina',
#   'Perkins',
#   'tina.perkins.133@gslingacademy.com',
#   'female',
#   0,
#   4,
#   0,
#   27,
#   'Software Engineer',
#   90,
#   63,
#   69,
#   80,
#   99,
#   69,
#   79,
#   549),
#  (134,
#   'Cory',
#   'Perez',
#   'cory.perez.134@gslingacademy.com',
#   'male',
#   1,
#   6,
#   0,
#   0,
#   'Business Owner',
#   88,
#   52,
#   53,
#   56,
#   85,
#   93,
#   78,
#   505),
#  (135,
#   'Christopher',
#   'Jenkins',
#   'christopher.jenkins.135@gslingacademy.com',
#   'male',
#   0,
#   1,
#   0,
#   3,
#   'Designer',
#   87,
#   62,
#   87,
#   96,
#   85,
#   90,
#   74,
#   581),
#  (136,
#   'Joanne',
#   'Campos',
#   'joanne.campos.136@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   6,
#   'Designer',
#   62,
#   83,
#   84,
#   75,
#   83,
#   85,
#   86,
#   558),
#  (137,
#   'David',
#   'Patel',
#   'david.patel.137@gslingacademy.com',
#   'male',
#   0,
#   2,
#   0,
#   12,
#   'Banker',
#   85,
#   65,
#   60,
#   78,
#   81,
#   96,
#   76,
#   541),
#  (138,
#   'Michelle',
#   'Hill',
#   'michelle.hill.138@gslingacademy.com',
#   'female',
#   0,
#   1,
#   1,
#   11,
#   'Banker',
#   79,
#   97,
#   76,
#   67,
#   61,
#   90,
#   95,
#   565),
#  (139,
#   'Jessica',
#   'Boyd',
#   'jessica.boyd.139@gslingacademy.com',
#   'female',
#   0,
#   4,
#   0,
#   23,
#   'Software Engineer',
#   90,
#   94,
#   98,
#   96,
#   68,
#   82,
#   81,
#   609),
#  (140,
#   'Lawrence',
#   'Russell',
#   'lawrence.russell.140@gslingacademy.com',
#   'male',
#   0,
#   2,
#   0,
#   23,
#   'Doctor',
#   97,
#   71,
#   82,
#   80,
#   97,
#   93,
#   78,
#   598),
#  (141,
#   'James',
#   'Singh',
#   'james.singh.141@gslingacademy.com',
#   'male',
#   0,
#   0,
#   0,
#   16,
#   'Software Engineer',
#   88,
#   69,
#   87,
#   81,
#   77,
#   67,
#   93,
#   562),
#  (142,
#   'Marc',
#   'Villanueva',
#   'marc.villanueva.142@gslingacademy.com',
#   'male',
#   1,
#   2,
#   1,
#   3,
#   'Artist',
#   71,
#   85,
#   77,
#   89,
#   98,
#   63,
#   100,
#   583),
#  (143,
#   'Cathy',
#   'Wilson',
#   'cathy.wilson.143@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   29,
#   'Lawyer',
#   70,
#   99,
#   79,
#   96,
#   60,
#   97,
#   100,
#   601),
#  (144,
#   'Adam',
#   'Mitchell',
#   'adam.mitchell.144@gslingacademy.com',
#   'male',
#   0,
#   3,
#   1,
#   18,
#   'Software Engineer',
#   93,
#   68,
#   76,
#   99,
#   80,
#   80,
#   75,
#   571),
#  (145,
#   'Sherry',
#   'Phillips',
#   'sherry.phillips.145@gslingacademy.com',
#   'female',
#   0,
#   0,
#   0,
#   3,
#   'Game Developer',
#   92,
#   79,
#   81,
#   61,
#   86,
#   72,
#   88,
#   559),
#  (146,
#   'Victor',
#   'Jones',
#   'victor.jones.146@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   6,
#   'Real Estate Developer',
#   83,
#   72,
#   68,
#   94,
#   100,
#   98,
#   92,
#   607),
#  (147,
#   'Mark',
#   'Young',
#   'mark.young.147@gslingacademy.com',
#   'male',
#   0,
#   8,
#   0,
#   2,
#   'Business Owner',
#   68,
#   97,
#   51,
#   93,
#   68,
#   58,
#   78,
#   513),
#  (148,
#   'Matthew',
#   'Jackson',
#   'matthew.jackson.148@gslingacademy.com',
#   'male',
#   0,
#   0,
#   0,
#   34,
#   'Lawyer',
#   92,
#   90,
#   65,
#   79,
#   96,
#   87,
#   74,
#   583),
#  (149,
#   'Tanya',
#   'Nichols',
#   'tanya.nichols.149@gslingacademy.com',
#   'female',
#   0,
#   4,
#   1,
#   22,
#   'Software Engineer',
#   69,
#   91,
#   82,
#   99,
#   94,
#   75,
#   74,
#   584),
#  (150,
#   'Julie',
#   'Gray',
#   'julie.gray.150@gslingacademy.com',
#   'female',
#   1,
#   5,
#   0,
#   4,
#   'Business Owner',
#   76,
#   72,
#   72,
#   65,
#   82,
#   71,
#   93,
#   531),
#  (151,
#   'Courtney',
#   'Perry',
#   'courtney.perry.151@gslingacademy.com',
#   'female',
#   0,
#   3,
#   0,
#   3,
#   'Software Engineer',
#   86,
#   92,
#   79,
#   73,
#   73,
#   61,
#   60,
#   524),
#  (152,
#   'Stephen',
#   'Rodriguez',
#   'stephen.rodriguez.152@gslingacademy.com',
#   'male',
#   1,
#   10,
#   0,
#   2,
#   'Business Owner',
#   41,
#   57,
#   97,
#   56,
#   50,
#   98,
#   83,
#   482),
#  (153,
#   'Elizabeth',
#   'Robinson',
#   'elizabeth.robinson.153@gslingacademy.com',
#   'female',
#   0,
#   5,
#   0,
#   18,
#   'Software Engineer',
#   91,
#   100,
#   84,
#   72,
#   84,
#   90,
#   82,
#   603),
#  (154,
#   'William',
#   'Graves',
#   'william.graves.154@gslingacademy.com',
#   'male',
#   0,
#   0,
#   0,
#   8,
#   'Real Estate Developer',
#   78,
#   67,
#   82,
#   70,
#   65,
#   68,
#   81,
#   511),
#  (155,
#   'Nancy',
#   'Moore',
#   'nancy.moore.155@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   33,
#   'Software Engineer',
#   89,
#   73,
#   85,
#   84,
#   73,
#   81,
#   98,
#   583),
#  (156,
#   'Matthew',
#   'Newman',
#   'matthew.newman.156@gslingacademy.com',
#   'male',
#   0,
#   0,
#   1,
#   13,
#   'Software Engineer',
#   96,
#   71,
#   88,
#   74,
#   80,
#   92,
#   65,
#   566),
#  (157,
#   'Anita',
#   'Moore',
#   'anita.moore.157@gslingacademy.com',
#   'female',
#   0,
#   0,
#   1,
#   17,
#   'Software Engineer',
#   66,
#   99,
#   85,
#   90,
#   76,
#   64,
#   95,
#   575),
#  (158,
#   'Brian',
#   'Sanchez',
#   'brian.sanchez.158@gslingacademy.com',
#   'male',
#   1,
#   8,
#   0,
#   1,
#   'Business Owner',
#   97,
#   54,
#   62,
#   66,
#   58,
#   69,
#   96,
#   502),
#  (159,
#   'Dennis',
#   'Phillips',
#   'dennis.phillips.159@gslingacademy.com',
#   'male',
#   1,
#   7,
#   1,
#   3,
#   'Business Owner',
#   49,
#   64,
#   97,
#   61,
#   62,
#   72,
#   65,
#   470),
#  (160,
#   'Michael',
#   'Rivas',
#   'michael.rivas.160@gslingacademy.com',
#   'male',
#   1,
#   4,
#   1,
#   33,
#   'Software Engineer',
#   88,
#   66,
#   96,
#   82,
#   65,
#   76,
#   79,
#   552),
#  (161,
#   'Ryan',
#   'Smith',
#   'ryan.smith.161@gslingacademy.com',
#   'male',
#   0,
#   1,
#   0,
#   12,
#   'Software Engineer',
#   92,
#   64,
#   77,
#   61,
#   76,
#   72,
#   87,
#   529),
#  (162,
#   'Anthony',
#   'Sullivan',
#   'anthony.sullivan.162@gslingacademy.com',
#   'male',
#   1,
#   3,
#   0,
#   24,
#   'Construction Engineer',
#   96,
#   66,
#   92,
#   88,
#   65,
#   76,
#   72,
#   555),
#  (163,
#   'Troy',
#   'Shepherd',
#   'troy.shepherd.163@gslingacademy.com',
#   'male',
#   0,
#   4,
#   0,
#   33,
#   'Construction Engineer',
#   86,
#   88,
#   99,
#   79,
#   93,
#   97,
#   91,
#   633),
#  (164,
#   'Nicholas',
#   'Clayton',
#   'nicholas.clayton.164@gslingacademy.com',
#   'male',
#   0,
#   1,
#   1,
#   44,
#   'Doctor',
#   86,
#   100,
#   100,
#   96,
#   95,
#   97,
#   93,
#   667),
#  (165,
#   'Denise',
#   'Schneider',
#   'denise.schneider.165@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   15,
#   'Teacher',
#   88,
#   72,
#   96,
#   60,
#   90,
#   80,
#   88,
#   574),
#  (166,
#   'Lisa',
#   'Silva',
#   'lisa.silva.166@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   5,
#   'Game Developer',
#   92,
#   81,
#   99,
#   98,
#   77,
#   80,
#   73,
#   600),
#  (167,
#   'Laura',
#   'Reilly',
#   'laura.reilly.167@gslingacademy.com',
#   'female',
#   1,
#   7,
#   0,
#   5,
#   'Business Owner',
#   87,
#   76,
#   71,
#   65,
#   64,
#   81,
#   61,
#   505),
#  (168,
#   'Amy',
#   'Peterson',
#   'amy.peterson.168@gslingacademy.com',
#   'female',
#   0,
#   5,
#   0,
#   22,
#   'Software Engineer',
#   89,
#   94,
#   67,
#   68,
#   69,
#   92,
#   76,
#   555),
#  (169,
#   'Fernando',
#   'Sexton',
#   'fernando.sexton.169@gslingacademy.com',
#   'male',
#   0,
#   1,
#   0,
#   9,
#   'Software Engineer',
#   97,
#   96,
#   66,
#   96,
#   71,
#   97,
#   66,
#   589),
#  (170,
#   'Evan',
#   'Christian',
#   'evan.christian.170@gslingacademy.com',
#   'male',
#   0,
#   4,
#   1,
#   34,
#   'Software Engineer',
#   100,
#   62,
#   67,
#   97,
#   73,
#   84,
#   99,
#   582),
#  (171,
#   'Rebecca',
#   'Norris',
#   'rebecca.norris.171@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   34,
#   'Lawyer',
#   91,
#   98,
#   76,
#   99,
#   65,
#   98,
#   71,
#   598),
#  (172,
#   'Erica',
#   'Marks',
#   'erica.marks.172@gslingacademy.com',
#   'female',
#   0,
#   4,
#   0,
#   25,
#   'Stock Investor',
#   81,
#   87,
#   65,
#   85,
#   74,
#   64,
#   81,
#   537),
#  (173,
#   'Rhonda',
#   'Webster',
#   'rhonda.webster.173@gslingacademy.com',
#   'female',
#   0,
#   5,
#   1,
#   31,
#   'Accountant',
#   82,
#   66,
#   89,
#   76,
#   68,
#   83,
#   79,
#   543),
#  (174,
#   'John',
#   'Bennett',
#   'john.bennett.174@gslingacademy.com',
#   'male',
#   0,
#   1,
#   0,
#   33,
#   'Lawyer',
#   100,
#   96,
#   75,
#   68,
#   77,
#   97,
#   81,
#   594),
#  (175,
#   'Amanda',
#   'Murphy',
#   'amanda.murphy.175@gslingacademy.com',
#   'female',
#   0,
#   10,
#   1,
#   3,
#   'Business Owner',
#   65,
#   100,
#   80,
#   83,
#   57,
#   81,
#   81,
#   547),
#  (176,
#   'Jeremy',
#   'Barnes',
#   'jeremy.barnes.176@gslingacademy.com',
#   'male',
#   0,
#   2,
#   0,
#   20,
#   'Software Engineer',
#   68,
#   100,
#   89,
#   75,
#   84,
#   78,
#   90,
#   584),
#  (177,
#   'John',
#   'Brown',
#   'john.brown.177@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   15,
#   'Accountant',
#   97,
#   92,
#   95,
#   75,
#   95,
#   90,
#   83,
#   627),
#  (178,
#   'Traci',
#   'Boyd',
#   'traci.boyd.178@gslingacademy.com',
#   'female',
#   0,
#   3,
#   0,
#   26,
#   'Banker',
#   76,
#   94,
#   77,
#   88,
#   85,
#   91,
#   61,
#   572),
#  (179,
#   'Elizabeth',
#   'Butler',
#   'elizabeth.butler.179@gslingacademy.com',
#   'female',
#   0,
#   5,
#   0,
#   35,
#   'Software Engineer',
#   91,
#   99,
#   94,
#   94,
#   95,
#   98,
#   89,
#   660),
#  (180,
#   'Alex',
#   'Clark',
#   'alex.clark.180@gslingacademy.com',
#   'male',
#   0,
#   4,
#   0,
#   12,
#   'Construction Engineer',
#   85,
#   73,
#   89,
#   73,
#   97,
#   66,
#   79,
#   562),
#  (181,
#   'Christopher',
#   'Wolfe',
#   'christopher.wolfe.181@gslingacademy.com',
#   'male',
#   0,
#   2,
#   1,
#   5,
#   'Software Engineer',
#   68,
#   69,
#   86,
#   87,
#   72,
#   80,
#   93,
#   555),
#  (182,
#   'Jason',
#   'Bell',
#   'jason.bell.182@gslingacademy.com',
#   'male',
#   0,
#   1,
#   0,
#   31,
#   'Lawyer',
#   73,
#   99,
#   75,
#   70,
#   100,
#   86,
#   62,
#   565),
#  (183,
#   'Victoria',
#   'Donaldson',
#   'victoria.donaldson.183@gslingacademy.com',
#   'female',
#   0,
#   3,
#   1,
#   28,
#   'Software Engineer',
#   65,
#   90,
#   75,
#   96,
#   91,
#   93,
#   85,
#   595),
#  (184,
#   'Logan',
#   'Cox',
#   'logan.cox.184@gslingacademy.com',
#   'male',
#   0,
#   8,
#   1,
#   5,
#   'Business Owner',
#   46,
#   79,
#   75,
#   86,
#   91,
#   88,
#   77,
#   542),
#  (185,
#   'Rachel',
#   'Hill',
#   'rachel.hill.185@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   33,
#   'Software Engineer',
#   92,
#   84,
#   85,
#   77,
#   81,
#   69,
#   95,
#   583),
#  (186,
#   'Jenny',
#   'Lloyd',
#   'jenny.lloyd.186@gslingacademy.com',
#   'female',
#   0,
#   3,
#   0,
#   2,
#   'Artist',
#   69,
#   78,
#   69,
#   70,
#   100,
#   88,
#   85,
#   559),
#  (187,
#   'Joan',
#   'Cohen',
#   'joan.cohen.187@gslingacademy.com',
#   'female',
#   0,
#   5,
#   1,
#   9,
#   'Real Estate Developer',
#   78,
#   99,
#   64,
#   99,
#   65,
#   84,
#   80,
#   569),
#  (188,
#   'Kimberly',
#   'Lopez',
#   'kimberly.lopez.188@gslingacademy.com',
#   'female',
#   1,
#   2,
#   1,
#   0,
#   'Business Owner',
#   92,
#   62,
#   86,
#   97,
#   54,
#   76,
#   76,
#   543),
#  (189,
#   'Steven',
#   'Walker',
#   'steven.walker.189@gslingacademy.com',
#   'male',
#   0,
#   5,
#   0,
#   26,
#   'Software Engineer',
#   70,
#   77,
#   91,
#   96,
#   100,
#   89,
#   67,
#   590),
#  (190,
#   'Sonia',
#   'Bowers',
#   'sonia.bowers.190@gslingacademy.com',
#   'female',
#   0,
#   5,
#   0,
#   30,
#   'Scientist',
#   95,
#   79,
#   98,
#   95,
#   89,
#   99,
#   87,
#   642),
#  (191,
#   'Penny',
#   'Perez',
#   'penny.perez.191@gslingacademy.com',
#   'female',
#   0,
#   7,
#   0,
#   1,
#   'Game Developer',
#   99,
#   82,
#   93,
#   83,
#   92,
#   90,
#   60,
#   599),
#  (192,
#   'Mike',
#   'Harris',
#   'mike.harris.192@gslingacademy.com',
#   'male',
#   0,
#   1,
#   1,
#   26,
#   'Software Engineer',
#   96,
#   66,
#   79,
#   80,
#   88,
#   61,
#   85,
#   555),
#  (193,
#   'Vanessa',
#   'Sweeney',
#   'vanessa.sweeney.193@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   2,
#   'Game Developer',
#   85,
#   90,
#   85,
#   74,
#   96,
#   71,
#   80,
#   581),
#  (194,
#   'Adam',
#   'Edwards',
#   'adam.edwards.194@gslingacademy.com',
#   'male',
#   0,
#   5,
#   0,
#   9,
#   'Stock Investor',
#   91,
#   94,
#   82,
#   100,
#   68,
#   66,
#   69,
#   570),
#  (195,
#   'Angelica',
#   'Johnson',
#   'angelica.johnson.195@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   30,
#   'Scientist',
#   85,
#   64,
#   93,
#   80,
#   82,
#   70,
#   94,
#   568),
#  (196,
#   'Tiffany',
#   'Hernandez',
#   'tiffany.hernandez.196@gslingacademy.com',
#   'female',
#   0,
#   3,
#   0,
#   24,
#   'Stock Investor',
#   94,
#   73,
#   61,
#   68,
#   65,
#   85,
#   67,
#   513),
#  (197,
#   'Mark',
#   'Myers',
#   'mark.myers.197@gslingacademy.com',
#   'male',
#   0,
#   4,
#   0,
#   21,
#   'Software Engineer',
#   95,
#   69,
#   62,
#   87,
#   84,
#   83,
#   64,
#   544),
#  (198,
#   'Erica',
#   'Cochran',
#   'erica.cochran.198@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   14,
#   'Teacher',
#   69,
#   90,
#   83,
#   70,
#   83,
#   91,
#   67,
#   553),
#  (199,
#   'Karen',
#   'Watson',
#   'karen.watson.199@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   24,
#   'Software Engineer',
#   95,
#   72,
#   94,
#   96,
#   91,
#   61,
#   94,
#   603),
#  (200,
#   'Kathryn',
#   'Frazier',
#   'kathryn.frazier.200@gslingacademy.com',
#   'female',
#   0,
#   3,
#   0,
#   34,
#   'Lawyer',
#   94,
#   88,
#   65,
#   88,
#   60,
#   81,
#   78,
#   554),
#  (201,
#   'Anthony',
#   'Jackson',
#   'anthony.jackson.201@gslingacademy.com',
#   'male',
#   0,
#   1,
#   1,
#   34,
#   'Accountant',
#   82,
#   81,
#   100,
#   81,
#   60,
#   79,
#   96,
#   579),
#  (202,
#   'Jordan',
#   'Perez',
#   'jordan.perez.202@gslingacademy.com',
#   'male',
#   0,
#   6,
#   1,
#   27,
#   'Software Engineer',
#   99,
#   73,
#   91,
#   91,
#   93,
#   80,
#   100,
#   627),
#  (203,
#   'Jennifer',
#   'Burgess',
#   'jennifer.burgess.203@gslingacademy.com',
#   'female',
#   0,
#   3,
#   0,
#   16,
#   'Accountant',
#   85,
#   62,
#   84,
#   80,
#   37,
#   80,
#   71,
#   499),
#  (204,
#   'Christina',
#   'Davis',
#   'christina.davis.204@gslingacademy.com',
#   'female',
#   0,
#   1,
#   1,
#   21,
#   'Accountant',
#   100,
#   87,
#   60,
#   92,
#   46,
#   67,
#   96,
#   548),
#  (205,
#   'April',
#   'Ryan',
#   'april.ryan.205@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   1,
#   'Artist',
#   98,
#   95,
#   90,
#   81,
#   82,
#   86,
#   98,
#   630),
#  (206,
#   'Maxwell',
#   'Davis',
#   'maxwell.davis.206@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   17,
#   'Software Engineer',
#   97,
#   78,
#   81,
#   67,
#   90,
#   95,
#   79,
#   587),
#  (207,
#   'Matthew',
#   'Guzman',
#   'matthew.guzman.207@gslingacademy.com',
#   'male',
#   0,
#   5,
#   0,
#   0,
#   'Software Engineer',
#   99,
#   86,
#   68,
#   94,
#   97,
#   77,
#   92,
#   613),
#  (208,
#   'Robert',
#   'Mayer',
#   'robert.mayer.208@gslingacademy.com',
#   'male',
#   0,
#   3,
#   1,
#   12,
#   'Accountant',
#   99,
#   73,
#   77,
#   74,
#   62,
#   68,
#   99,
#   552),
#  (209,
#   'Amanda',
#   'Willis',
#   'amanda.willis.209@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   22,
#   'Banker',
#   75,
#   83,
#   70,
#   71,
#   86,
#   95,
#   76,
#   556),
#  (210,
#   'Michele',
#   'Thomas',
#   'michele.thomas.210@gslingacademy.com',
#   'female',
#   0,
#   1,
#   1,
#   14,
#   'Teacher',
#   63,
#   80,
#   99,
#   78,
#   60,
#   84,
#   86,
#   550),
#  (211,
#   'Tim',
#   'Turner',
#   'tim.turner.211@gslingacademy.com',
#   'male',
#   0,
#   0,
#   0,
#   41,
#   'Doctor',
#   96,
#   88,
#   90,
#   100,
#   94,
#   87,
#   96,
#   651),
#  (212,
#   'Joe',
#   'Strickland',
#   'joe.strickland.212@gslingacademy.com',
#   'male',
#   0,
#   4,
#   0,
#   32,
#   'Construction Engineer',
#   91,
#   73,
#   86,
#   73,
#   84,
#   60,
#   71,
#   538),
#  (213,
#   'Trevor',
#   'Cruz',
#   'trevor.cruz.213@gslingacademy.com',
#   'male',
#   1,
#   1,
#   0,
#   4,
#   'Business Owner',
#   52,
#   58,
#   60,
#   97,
#   93,
#   89,
#   68,
#   517),
#  (214,
#   'Melissa',
#   'Roberts',
#   'melissa.roberts.214@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   22,
#   'Doctor',
#   99,
#   71,
#   80,
#   82,
#   95,
#   64,
#   64,
#   555),
#  (215,
#   'Tammy',
#   'Miller',
#   'tammy.miller.215@gslingacademy.com',
#   'female',
#   0,
#   3,
#   0,
#   17,
#   'Banker',
#   84,
#   62,
#   92,
#   74,
#   73,
#   98,
#   91,
#   574),
#  (216,
#   'Chad',
#   'Morgan',
#   'chad.morgan.216@gslingacademy.com',
#   'male',
#   0,
#   2,
#   0,
#   2,
#   'Artist',
#   100,
#   90,
#   82,
#   79,
#   94,
#   83,
#   78,
#   606),
#  (217,
#   'Samantha',
#   'Maldonado',
#   'samantha.maldonado.217@gslingacademy.com',
#   'female',
#   0,
#   4,
#   0,
#   33,
#   'Banker',
#   82,
#   71,
#   93,
#   90,
#   90,
#   76,
#   97,
#   599),
#  (218,
#   'Marie',
#   'Martin',
#   'marie.martin.218@gslingacademy.com',
#   'female',
#   0,
#   5,
#   0,
#   29,
#   'Banker',
#   75,
#   88,
#   65,
#   80,
#   76,
#   94,
#   97,
#   575),
#  (219,
#   'Theresa',
#   'Tucker',
#   'theresa.tucker.219@gslingacademy.com',
#   'female',
#   1,
#   1,
#   0,
#   27,
#   'Software Engineer',
#   66,
#   71,
#   94,
#   72,
#   96,
#   70,
#   63,
#   532),
#  (220,
#   'Joseph',
#   'Morris',
#   'joseph.morris.220@gslingacademy.com',
#   'male',
#   0,
#   6,
#   1,
#   34,
#   'Banker',
#   99,
#   88,
#   72,
#   76,
#   68,
#   92,
#   72,
#   567),
#  (221,
#   'Charles',
#   'Parker',
#   'charles.parker.221@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   2,
#   'Real Estate Developer',
#   99,
#   76,
#   94,
#   88,
#   75,
#   66,
#   84,
#   582),
#  (222,
#   'Rachel',
#   'Alvarez',
#   'rachel.alvarez.222@gslingacademy.com',
#   'female',
#   0,
#   3,
#   0,
#   22,
#   'Software Engineer',
#   95,
#   87,
#   79,
#   95,
#   84,
#   90,
#   74,
#   604),
#  (223,
#   'Charles',
#   'Robertson',
#   'charles.robertson.223@gslingacademy.com',
#   'male',
#   0,
#   7,
#   0,
#   33,
#   'Software Engineer',
#   99,
#   61,
#   75,
#   68,
#   66,
#   90,
#   99,
#   558),
#  (224,
#   'Steven',
#   'York',
#   'steven.york.224@gslingacademy.com',
#   'male',
#   0,
#   5,
#   0,
#   17,
#   'Designer',
#   65,
#   72,
#   96,
#   69,
#   78,
#   93,
#   72,
#   545),
#  (225,
#   'Robert',
#   'Dougherty',
#   'robert.dougherty.225@gslingacademy.com',
#   'male',
#   0,
#   7,
#   0,
#   4,
#   'Business Owner',
#   85,
#   55,
#   74,
#   71,
#   66,
#   50,
#   99,
#   500),
#  (226,
#   'Vanessa',
#   'Wheeler',
#   'vanessa.wheeler.226@gslingacademy.com',
#   'female',
#   0,
#   7,
#   1,
#   3,
#   'Business Owner',
#   69,
#   78,
#   57,
#   72,
#   71,
#   96,
#   87,
#   530),
#  (227,
#   'Emily',
#   'Mcclure',
#   'emily.mcclure.227@gslingacademy.com',
#   'female',
#   0,
#   7,
#   0,
#   3,
#   'Business Owner',
#   75,
#   76,
#   88,
#   65,
#   97,
#   83,
#   85,
#   569),
#  (228,
#   'Angela',
#   'Thomas',
#   'angela.thomas.228@gslingacademy.com',
#   'female',
#   0,
#   7,
#   1,
#   17,
#   'Software Engineer',
#   91,
#   78,
#   72,
#   69,
#   77,
#   91,
#   96,
#   574),
#  (229,
#   'Roberto',
#   'Evans',
#   'roberto.evans.229@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   6,
#   'Real Estate Developer',
#   92,
#   95,
#   61,
#   98,
#   89,
#   85,
#   80,
#   600),
#  (230,
#   'Christopher',
#   'Perez',
#   'christopher.perez.230@gslingacademy.com',
#   'male',
#   0,
#   7,
#   0,
#   9,
#   'Software Engineer',
#   62,
#   64,
#   65,
#   86,
#   67,
#   94,
#   68,
#   506),
#  (231,
#   'William',
#   'Torres',
#   'william.torres.231@gslingacademy.com',
#   'male',
#   1,
#   2,
#   0,
#   35,
#   'Software Engineer',
#   87,
#   91,
#   98,
#   94,
#   100,
#   87,
#   89,
#   646),
#  (232,
#   'Lisa',
#   'Gardner',
#   'lisa.gardner.232@gslingacademy.com',
#   'female',
#   0,
#   3,
#   0,
#   17,
#   'Software Engineer',
#   97,
#   88,
#   87,
#   61,
#   86,
#   92,
#   94,
#   605),
#  (233,
#   'Catherine',
#   'Owens',
#   'catherine.owens.233@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   7,
#   'Government Officer',
#   97,
#   92,
#   79,
#   88,
#   92,
#   99,
#   85,
#   632),
#  (234,
#   'Keith',
#   'Summers',
#   'keith.summers.234@gslingacademy.com',
#   'male',
#   0,
#   5,
#   0,
#   16,
#   'Designer',
#   98,
#   88,
#   92,
#   84,
#   90,
#   90,
#   71,
#   613),
#  (235,
#   'Linda',
#   'Adams',
#   'linda.adams.235@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   20,
#   'Software Engineer',
#   96,
#   67,
#   88,
#   95,
#   82,
#   75,
#   84,
#   587),
#  (236,
#   'Michael',
#   'Wright',
#   'michael.wright.236@gslingacademy.com',
#   'male',
#   1,
#   7,
#   0,
#   0,
#   'Business Owner',
#   98,
#   89,
#   81,
#   56,
#   72,
#   74,
#   94,
#   564),
#  (237,
#   'Kyle',
#   'James',
#   'kyle.james.237@gslingacademy.com',
#   'male',
#   0,
#   2,
#   0,
#   27,
#   'Lawyer',
#   87,
#   82,
#   95,
#   81,
#   85,
#   84,
#   73,
#   587),
#  (238,
#   'Christopher',
#   'Cook',
#   'christopher.cook.238@gslingacademy.com',
#   'male',
#   0,
#   0,
#   0,
#   24,
#   'Construction Engineer',
#   96,
#   80,
#   86,
#   94,
#   63,
#   72,
#   75,
#   566),
#  (239,
#   'John',
#   'Conley',
#   'john.conley.239@gslingacademy.com',
#   'male',
#   0,
#   2,
#   0,
#   30,
#   'Software Engineer',
#   82,
#   74,
#   77,
#   95,
#   81,
#   76,
#   91,
#   576),
#  (240,
#   'David',
#   'Barnett',
#   'david.barnett.240@gslingacademy.com',
#   'male',
#   0,
#   6,
#   0,
#   20,
#   'Software Engineer',
#   100,
#   72,
#   99,
#   64,
#   70,
#   93,
#   67,
#   565),
#  (241,
#   'Peter',
#   'Garner',
#   'peter.garner.241@gslingacademy.com',
#   'male',
#   0,
#   0,
#   0,
#   27,
#   'Software Engineer',
#   91,
#   81,
#   91,
#   76,
#   100,
#   92,
#   87,
#   618),
#  (242,
#   'Douglas',
#   'Stewart',
#   'douglas.stewart.242@gslingacademy.com',
#   'male',
#   0,
#   6,
#   0,
#   2,
#   'Business Owner',
#   87,
#   62,
#   85,
#   64,
#   63,
#   61,
#   85,
#   507),
#  (243,
#   'Heidi',
#   'Jones',
#   'heidi.jones.243@gslingacademy.com',
#   'female',
#   0,
#   6,
#   0,
#   16,
#   'Banker',
#   75,
#   95,
#   84,
#   87,
#   78,
#   82,
#   86,
#   587),
#  (244,
#   'Jeremy',
#   'Daniels',
#   'jeremy.daniels.244@gslingacademy.com',
#   'male',
#   1,
#   1,
#   0,
#   27,
#   'Banker',
#   86,
#   78,
#   61,
#   71,
#   94,
#   92,
#   65,
#   547),
#  (245,
#   'Dustin',
#   'Dodson',
#   'dustin.dodson.245@gslingacademy.com',
#   'male',
#   0,
#   4,
#   1,
#   24,
#   'Accountant',
#   94,
#   62,
#   97,
#   96,
#   74,
#   68,
#   69,
#   560),
#  (246,
#   'Christopher',
#   'Cohen',
#   'christopher.cohen.246@gslingacademy.com',
#   'male',
#   0,
#   4,
#   0,
#   23,
#   'Accountant',
#   99,
#   64,
#   92,
#   78,
#   30,
#   78,
#   88,
#   529),
#  (247,
#   'Willie',
#   'Ellis',
#   'willie.ellis.247@gslingacademy.com',
#   'male',
#   0,
#   1,
#   0,
#   15,
#   'Government Officer',
#   84,
#   91,
#   94,
#   66,
#   78,
#   71,
#   93,
#   577),
#  (248,
#   'Robert',
#   'Hawkins',
#   'robert.hawkins.248@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   25,
#   'Stock Investor',
#   92,
#   81,
#   68,
#   96,
#   99,
#   92,
#   79,
#   607),
#  (249,
#   'Stacy',
#   'Jordan',
#   'stacy.jordan.249@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   32,
#   'Software Engineer',
#   95,
#   84,
#   95,
#   72,
#   62,
#   80,
#   83,
#   571),
#  (250,
#   'Robert',
#   'Swanson',
#   'robert.swanson.250@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   35,
#   'Lawyer',
#   90,
#   88,
#   94,
#   99,
#   92,
#   87,
#   97,
#   647),
#  (251,
#   'Holly',
#   'Henderson',
#   'holly.henderson.251@gslingacademy.com',
#   'female',
#   0,
#   3,
#   0,
#   3,
#   'Artist',
#   93,
#   100,
#   87,
#   66,
#   85,
#   96,
#   87,
#   614),
#  (252,
#   'Debra',
#   'Valdez',
#   'debra.valdez.252@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   28,
#   'Designer',
#   69,
#   63,
#   88,
#   73,
#   83,
#   74,
#   94,
#   544),
#  (253,
#   'Vincent',
#   'Robertson',
#   'vincent.robertson.253@gslingacademy.com',
#   'male',
#   0,
#   1,
#   0,
#   3,
#   'Game Developer',
#   97,
#   80,
#   80,
#   65,
#   91,
#   67,
#   84,
#   564),
#  (254,
#   'Karen',
#   'Spencer',
#   'karen.spencer.254@gslingacademy.com',
#   'female',
#   0,
#   0,
#   0,
#   21,
#   'Accountant',
#   76,
#   72,
#   80,
#   92,
#   41,
#   90,
#   78,
#   529),
#  (255,
#   'Nathan',
#   'Riley',
#   'nathan.riley.255@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   35,
#   'Software Engineer',
#   85,
#   85,
#   92,
#   86,
#   99,
#   86,
#   93,
#   626),
#  (256,
#   'Andrea',
#   'Sutton',
#   'andrea.sutton.256@gslingacademy.com',
#   'female',
#   0,
#   7,
#   1,
#   35,
#   'Software Engineer',
#   91,
#   87,
#   89,
#   97,
#   93,
#   87,
#   100,
#   644),
#  (257,
#   'Tracey',
#   'Turner',
#   'tracey.turner.257@gslingacademy.com',
#   'female',
#   0,
#   7,
#   1,
#   14,
#   'Accountant',
#   82,
#   95,
#   92,
#   62,
#   73,
#   75,
#   93,
#   572),
#  (258,
#   'Tammy',
#   'Olsen',
#   'tammy.olsen.258@gslingacademy.com',
#   'female',
#   1,
#   7,
#   0,
#   1,
#   'Business Owner',
#   59,
#   56,
#   87,
#   97,
#   62,
#   74,
#   61,
#   496),
#  (259,
#   'Sheila',
#   'Wilkinson',
#   'sheila.wilkinson.259@gslingacademy.com',
#   'female',
#   0,
#   9,
#   1,
#   0,
#   'Business Owner',
#   78,
#   71,
#   73,
#   51,
#   80,
#   84,
#   65,
#   502),
#  (260,
#   'Nathan',
#   'Padilla',
#   'nathan.padilla.260@gslingacademy.com',
#   'male',
#   0,
#   2,
#   0,
#   12,
#   'Construction Engineer',
#   89,
#   65,
#   82,
#   65,
#   76,
#   95,
#   62,
#   534),
#  (261,
#   'Sarah',
#   'Santiago',
#   'sarah.santiago.261@gslingacademy.com',
#   'female',
#   0,
#   3,
#   0,
#   35,
#   'Software Engineer',
#   86,
#   91,
#   92,
#   96,
#   90,
#   96,
#   90,
#   641),
#  (262,
#   'Christopher',
#   'Cruz',
#   'christopher.cruz.262@gslingacademy.com',
#   'male',
#   0,
#   4,
#   0,
#   2,
#   'Artist',
#   76,
#   93,
#   65,
#   95,
#   76,
#   88,
#   88,
#   581),
#  (263,
#   'Nicholas',
#   'Sanders',
#   'nicholas.sanders.263@gslingacademy.com',
#   'male',
#   1,
#   2,
#   0,
#   16,
#   'Software Engineer',
#   79,
#   68,
#   63,
#   72,
#   81,
#   67,
#   67,
#   497),
#  (264,
#   'Jessica',
#   'Waters',
#   'jessica.waters.264@gslingacademy.com',
#   'female',
#   0,
#   3,
#   0,
#   31,
#   'Lawyer',
#   91,
#   96,
#   77,
#   76,
#   80,
#   97,
#   80,
#   597),
#  (265,
#   'James',
#   'Miller',
#   'james.miller.265@gslingacademy.com',
#   'male',
#   0,
#   5,
#   0,
#   4,
#   'Business Owner',
#   89,
#   66,
#   80,
#   77,
#   60,
#   88,
#   74,
#   534),
#  (266,
#   'Adam',
#   'Kane',
#   'adam.kane.266@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   19,
#   'Software Engineer',
#   97,
#   94,
#   81,
#   97,
#   79,
#   86,
#   63,
#   597),
#  (267,
#   'Patricia',
#   'Gonzalez',
#   'patricia.gonzalez.267@gslingacademy.com',
#   'female',
#   0,
#   3,
#   1,
#   15,
#   'Banker',
#   100,
#   86,
#   74,
#   96,
#   80,
#   99,
#   76,
#   611),
#  (268,
#   'Whitney',
#   'Holmes',
#   'whitney.holmes.268@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   30,
#   'Doctor',
#   96,
#   68,
#   87,
#   96,
#   91,
#   68,
#   65,
#   571),
#  (269,
#   'Rachel',
#   'Hamilton',
#   'rachel.hamilton.269@gslingacademy.com',
#   'female',
#   0,
#   7,
#   0,
#   17,
#   'Banker',
#   94,
#   64,
#   100,
#   71,
#   84,
#   92,
#   99,
#   604),
#  (270,
#   'Melissa',
#   'Marshall',
#   'melissa.marshall.270@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   23,
#   'Software Engineer',
#   98,
#   68,
#   80,
#   75,
#   80,
#   81,
#   60,
#   542),
#  (271,
#   'Jacob',
#   'Henderson',
#   'jacob.henderson.271@gslingacademy.com',
#   'male',
#   0,
#   1,
#   0,
#   3,
#   'Business Owner',
#   53,
#   71,
#   98,
#   95,
#   94,
#   71,
#   77,
#   559),
#  (272,
#   'Melissa',
#   'Huerta',
#   'melissa.huerta.272@gslingacademy.com',
#   'female',
#   0,
#   7,
#   0,
#   4,
#   'Business Owner',
#   44,
#   64,
#   58,
#   66,
#   87,
#   62,
#   68,
#   449),
#  (273,
#   'Kevin',
#   'Camacho',
#   'kevin.camacho.273@gslingacademy.com',
#   'male',
#   0,
#   0,
#   0,
#   25,
#   'Software Engineer',
#   85,
#   70,
#   73,
#   95,
#   100,
#   70,
#   94,
#   587),
#  (274,
#   'Anthony',
#   'Martinez',
#   'anthony.martinez.274@gslingacademy.com',
#   'male',
#   1,
#   10,
#   0,
#   1,
#   'Business Owner',
#   51,
#   91,
#   67,
#   79,
#   58,
#   52,
#   75,
#   473),
#  (275,
#   'Randy',
#   'Rodriguez',
#   'randy.rodriguez.275@gslingacademy.com',
#   'male',
#   0,
#   1,
#   0,
#   24,
#   'Lawyer',
#   90,
#   89,
#   82,
#   74,
#   67,
#   92,
#   82,
#   576),
#  (276,
#   'Patrick',
#   'Vazquez',
#   'patrick.vazquez.276@gslingacademy.com',
#   'male',
#   0,
#   1,
#   0,
#   15,
#   'Software Engineer',
#   100,
#   92,
#   90,
#   66,
#   73,
#   68,
#   70,
#   559),
#  (277,
#   'Kim',
#   'Flores',
#   'kim.flores.277@gslingacademy.com',
#   'female',
#   1,
#   7,
#   0,
#   1,
#   'Business Owner',
#   95,
#   73,
#   61,
#   91,
#   84,
#   92,
#   94,
#   590),
#  (278,
#   'Robert',
#   'Salazar',
#   'robert.salazar.278@gslingacademy.com',
#   'male',
#   0,
#   1,
#   1,
#   33,
#   'Lawyer',
#   76,
#   81,
#   96,
#   74,
#   75,
#   80,
#   98,
#   580),
#  (279,
#   'Victoria',
#   'Vasquez',
# ...
#   98,
#   93,
#   95,
#   99,
#   623),
#  (909,
#   'Ruben',
#   'Meyer',
#   'ruben.meyer.909@gslingacademy.com',
#   'male',
#   0,
#   8,
#   1,
#   12,
#   'Stock Investor',
#   100,
#   84,
#   73,
#   96,
#   97,
#   85,
#   63,
#   598),
#  (910,
#   'Megan',
#   'Alexander',
#   'megan.alexander.910@gslingacademy.com',
#   'female',
#   0,
#   3,
#   0,
#   27,
#   'Software Engineer',
#   90,
#   91,
#   88,
#   95,
#   98,
#   99,
#   71,
#   632),
#  (911,
#   'Jennifer',
#   'Gonzalez',
#   'jennifer.gonzalez.911@gslingacademy.com',
#   'female',
#   0,
#   4,
#   1,
#   12,
#   'Banker',
#   97,
#   77,
#   66,
#   93,
#   99,
#   78,
#   91,
#   601),
#  (912,
#   'Carl',
#   'Ferguson',
#   'carl.ferguson.912@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   21,
#   'Banker',
#   77,
#   93,
#   69,
#   75,
#   88,
#   81,
#   89,
#   572),
#  (913,
#   'Valerie',
#   'Romero',
#   'valerie.romero.913@gslingacademy.com',
#   'female',
#   0,
#   9,
#   0,
#   15,
#   'Teacher',
#   82,
#   61,
#   79,
#   84,
#   73,
#   95,
#   85,
#   559),
#  (914,
#   'Laura',
#   'Romero',
#   'laura.romero.914@gslingacademy.com',
#   'female',
#   0,
#   3,
#   0,
#   26,
#   'Software Engineer',
#   89,
#   68,
#   83,
#   88,
#   69,
#   79,
#   74,
#   550),
#  (915,
#   'Heidi',
#   'Adams',
#   'heidi.adams.915@gslingacademy.com',
#   'female',
#   1,
#   10,
#   0,
#   3,
#   'Business Owner',
#   43,
#   83,
#   58,
#   89,
#   87,
#   78,
#   86,
#   524),
#  (916,
#   'Regina',
#   'Spencer',
#   'regina.spencer.916@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   31,
#   'Lawyer',
#   86,
#   85,
#   66,
#   94,
#   62,
#   86,
#   92,
#   571),
#  (917,
#   'Lee',
#   'Campbell',
#   'lee.campbell.917@gslingacademy.com',
#   'male',
#   0,
#   9,
#   0,
#   31,
#   'Scientist',
#   92,
#   74,
#   95,
#   97,
#   87,
#   78,
#   68,
#   591),
#  (918,
#   'Noah',
#   'Mcdaniel',
#   'noah.mcdaniel.918@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   3,
#   'Software Engineer',
#   71,
#   70,
#   60,
#   84,
#   87,
#   87,
#   64,
#   523),
#  (919,
#   'Dorothy',
#   'Mitchell',
#   'dorothy.mitchell.919@gslingacademy.com',
#   'female',
#   0,
#   8,
#   0,
#   16,
#   'Software Engineer',
#   92,
#   81,
#   71,
#   97,
#   96,
#   72,
#   63,
#   572),
#  (920,
#   'Michael',
#   'Mccarthy',
#   'michael.mccarthy.920@gslingacademy.com',
#   'male',
#   0,
#   5,
#   0,
#   29,
#   'Lawyer',
#   77,
#   92,
#   65,
#   62,
#   76,
#   84,
#   100,
#   556),
#  (921,
#   'Matthew',
#   'Jones',
#   'matthew.jones.921@gslingacademy.com',
#   'male',
#   0,
#   4,
#   0,
#   31,
#   'Software Engineer',
#   90,
#   62,
#   87,
#   63,
#   77,
#   71,
#   68,
#   518),
#  (922,
#   'John',
#   'Riley',
#   'john.riley.922@gslingacademy.com',
#   'male',
#   0,
#   1,
#   0,
#   46,
#   'Doctor',
#   91,
#   85,
#   98,
#   96,
#   98,
#   96,
#   93,
#   657),
#  (923,
#   'Shelly',
#   'Dominguez',
#   'shelly.dominguez.923@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   24,
#   'Software Engineer',
#   88,
#   72,
#   96,
#   97,
#   71,
#   60,
#   61,
#   545),
#  (924,
#   'Ann',
#   'Evans',
#   'ann.evans.924@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   2,
#   'Real Estate Developer',
#   98,
#   73,
#   85,
#   78,
#   61,
#   74,
#   96,
#   565),
#  (925,
#   'David',
#   'Perez',
#   'david.perez.925@gslingacademy.com',
#   'male',
#   1,
#   10,
#   0,
#   2,
#   'Business Owner',
#   87,
#   60,
#   67,
#   88,
#   99,
#   56,
#   92,
#   549),
#  (926,
#   'Nicole',
#   'Bell',
#   'nicole.bell.926@gslingacademy.com',
#   'female',
#   0,
#   3,
#   0,
#   9,
#   'Teacher',
#   66,
#   64,
#   82,
#   82,
#   72,
#   96,
#   100,
#   562),
#  (927,
#   'Amanda',
#   'Garcia',
#   'amanda.garcia.927@gslingacademy.com',
#   'female',
#   1,
#   7,
#   0,
#   0,
#   'Business Owner',
#   83,
#   98,
#   51,
#   72,
#   90,
#   59,
#   73,
#   526),
#  (928,
#   'Charles',
#   'Owens',
#   'charles.owens.928@gslingacademy.com',
#   'male',
#   0,
#   8,
#   0,
#   4,
#   'Business Owner',
#   40,
#   94,
#   90,
#   68,
#   61,
#   77,
#   92,
#   522),
#  (929,
#   'Teresa',
#   'Henry',
#   'teresa.henry.929@gslingacademy.com',
#   'female',
#   0,
#   6,
#   0,
#   4,
#   'Business Owner',
#   43,
#   90,
#   78,
#   63,
#   68,
#   63,
#   72,
#   477),
#  (930,
#   'Luis',
#   'Frank',
#   'luis.frank.930@gslingacademy.com',
#   'male',
#   0,
#   4,
#   0,
#   34,
#   'Software Engineer',
#   100,
#   97,
#   74,
#   74,
#   82,
#   75,
#   69,
#   571),
#  (931,
#   'Timothy',
#   'Booth',
#   'timothy.booth.931@gslingacademy.com',
#   'male',
#   0,
#   2,
#   0,
#   34,
#   'Software Engineer',
#   93,
#   70,
#   74,
#   78,
#   94,
#   75,
#   96,
#   580),
#  (932,
#   'Michael',
#   'Moon',
#   'michael.moon.932@gslingacademy.com',
#   'male',
#   0,
#   5,
#   0,
#   32,
#   'Software Engineer',
#   98,
#   86,
#   82,
#   72,
#   79,
#   93,
#   94,
#   604),
#  (933,
#   'Rachel',
#   'Hall',
#   'rachel.hall.933@gslingacademy.com',
#   'female',
#   1,
#   4,
#   0,
#   23,
#   'Software Engineer',
#   90,
#   95,
#   73,
#   81,
#   81,
#   62,
#   81,
#   563),
#  (934,
#   'Thomas',
#   'Nguyen',
#   'thomas.nguyen.934@gslingacademy.com',
#   'male',
#   0,
#   2,
#   1,
#   20,
#   'Software Engineer',
#   90,
#   77,
#   86,
#   91,
#   76,
#   78,
#   62,
#   560),
#  (935,
#   'Tiffany',
#   'Fields',
#   'tiffany.fields.935@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   5,
#   'Artist',
#   68,
#   67,
#   65,
#   68,
#   63,
#   97,
#   63,
#   491),
#  (936,
#   'Jessica',
#   'Marshall',
#   'jessica.marshall.936@gslingacademy.com',
#   'female',
#   0,
#   5,
#   1,
#   15,
#   'Software Engineer',
#   91,
#   60,
#   98,
#   77,
#   72,
#   74,
#   63,
#   535),
#  (937,
#   'Maurice',
#   'Nguyen',
#   'maurice.nguyen.937@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   21,
#   'Designer',
#   87,
#   74,
#   92,
#   67,
#   85,
#   63,
#   87,
#   555),
#  (938,
#   'William',
#   'Kelly',
#   'william.kelly.938@gslingacademy.com',
#   'male',
#   0,
#   1,
#   0,
#   30,
#   'Software Engineer',
#   91,
#   90,
#   88,
#   92,
#   75,
#   98,
#   91,
#   625),
#  (939,
#   'Harry',
#   'Hunter',
#   'harry.hunter.939@gslingacademy.com',
#   'male',
#   0,
#   3,
#   1,
#   15,
#   'Accountant',
#   98,
#   72,
#   87,
#   74,
#   100,
#   84,
#   85,
#   600),
#  (940,
#   'Gary',
#   'Gentry',
#   'gary.gentry.940@gslingacademy.com',
#   'male',
#   0,
#   6,
#   1,
#   18,
#   'Banker',
#   85,
#   74,
#   79,
#   82,
#   71,
#   87,
#   67,
#   545),
#  (941,
#   'Maria',
#   'Malone',
#   'maria.malone.941@gslingacademy.com',
#   'female',
#   1,
#   10,
#   0,
#   4,
#   'Business Owner',
#   40,
#   97,
#   71,
#   70,
#   73,
#   81,
#   85,
#   517),
#  (942,
#   'Jason',
#   'Vazquez',
#   'jason.vazquez.942@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   24,
#   'Accountant',
#   76,
#   75,
#   76,
#   67,
#   60,
#   77,
#   100,
#   531),
#  (943,
#   'Patrick',
#   'West',
#   'patrick.west.943@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   15,
#   'Banker',
#   89,
#   76,
#   84,
#   93,
#   64,
#   86,
#   95,
#   587),
#  (944,
#   'Alexandra',
#   'Brown',
#   'alexandra.brown.944@gslingacademy.com',
#   'female',
#   0,
#   3,
#   0,
#   2,
#   'Artist',
#   76,
#   73,
#   74,
#   73,
#   81,
#   87,
#   84,
#   548),
#  (945,
#   'Jennifer',
#   'Torres',
#   'jennifer.torres.945@gslingacademy.com',
#   'female',
#   0,
#   6,
#   0,
#   14,
#   'Software Engineer',
#   91,
#   61,
#   100,
#   88,
#   73,
#   84,
#   100,
#   597),
#  (946,
#   'Daniel',
#   'Smith',
#   'daniel.smith.946@gslingacademy.com',
#   'male',
#   0,
#   1,
#   0,
#   5,
#   'Business Owner',
#   55,
#   58,
#   96,
#   88,
#   99,
#   98,
#   71,
#   565),
#  (947,
#   'Catherine',
#   'Boyle',
#   'catherine.boyle.947@gslingacademy.com',
#   'female',
#   0,
#   5,
#   0,
#   0,
#   'Real Estate Developer',
#   93,
#   88,
#   76,
#   73,
#   67,
#   88,
#   76,
#   561),
#  (948,
#   'Amanda',
#   'Bush',
#   'amanda.bush.948@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   10,
#   'Real Estate Developer',
#   84,
#   68,
#   60,
#   86,
#   90,
#   84,
#   81,
#   553),
#  (949,
#   'Emma',
#   'Copeland',
#   'emma.copeland.949@gslingacademy.com',
#   'female',
#   1,
#   5,
#   0,
#   2,
#   'Business Owner',
#   62,
#   65,
#   98,
#   52,
#   66,
#   94,
#   82,
#   519),
#  (950,
#   'Bradley',
#   'Avery',
#   'bradley.avery.950@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   30,
#   'Lawyer',
#   80,
#   81,
#   75,
#   72,
#   71,
#   84,
#   87,
#   550),
#  (951,
#   'Danielle',
#   'Martinez',
#   'danielle.martinez.951@gslingacademy.com',
#   'female',
#   0,
#   7,
#   0,
#   28,
#   'Doctor',
#   93,
#   84,
#   85,
#   94,
#   95,
#   74,
#   83,
#   608),
#  (952,
#   'Anna',
#   'Wolf',
#   'anna.wolf.952@gslingacademy.com',
#   'female',
#   0,
#   0,
#   1,
#   29,
#   'Lawyer',
#   92,
#   82,
#   63,
#   61,
#   66,
#   84,
#   98,
#   546),
#  (953,
#   'Megan',
#   'Whitaker',
#   'megan.whitaker.953@gslingacademy.com',
#   'female',
#   0,
#   0,
#   0,
#   35,
#   'Software Engineer',
#   87,
#   89,
#   91,
#   89,
#   93,
#   92,
#   95,
#   636),
#  (954,
#   'Melissa',
#   'Richard',
#   'melissa.richard.954@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   12,
#   'Banker',
#   83,
#   69,
#   93,
#   60,
#   98,
#   83,
#   88,
#   574),
#  (955,
#   'Richard',
#   'Small',
#   'richard.small.955@gslingacademy.com',
#   'male',
#   1,
#   3,
#   0,
#   32,
#   'Stock Investor',
#   95,
#   75,
#   87,
#   67,
#   96,
#   86,
#   85,
#   591),
#  (956,
#   'Victor',
#   'Phillips',
#   'victor.phillips.956@gslingacademy.com',
#   'male',
#   0,
#   2,
#   0,
#   27,
#   'Accountant',
#   79,
#   65,
#   92,
#   67,
#   78,
#   66,
#   98,
#   545),
#  (957,
#   'Madison',
#   'Callahan',
#   'madison.callahan.957@gslingacademy.com',
#   'female',
#   0,
#   4,
#   0,
#   25,
#   'Software Engineer',
#   87,
#   68,
#   84,
#   92,
#   96,
#   88,
#   60,
#   575),
#  (958,
#   'Connor',
#   'Olson',
#   'connor.olson.958@gslingacademy.com',
#   'male',
#   0,
#   10,
#   0,
#   11,
#   'Software Engineer',
#   94,
#   92,
#   76,
#   74,
#   65,
#   96,
#   87,
#   584),
#  (959,
#   'Hunter',
#   'Allen',
#   'hunter.allen.959@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   2,
#   'Game Developer',
#   82,
#   77,
#   95,
#   81,
#   83,
#   73,
#   76,
#   567),
#  (960,
#   'Shannon',
#   'Johnson',
#   'shannon.johnson.960@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   24,
#   'Banker',
#   90,
#   98,
#   89,
#   78,
#   74,
#   93,
#   65,
#   587),
#  (961,
#   'Samantha',
#   'Alexander',
#   'samantha.alexander.961@gslingacademy.com',
#   'female',
#   0,
#   4,
#   0,
#   16,
#   'Accountant',
#   100,
#   68,
#   62,
#   76,
#   72,
#   94,
#   89,
#   561),
#  (962,
#   'Justin',
#   'Lester',
#   'justin.lester.962@gslingacademy.com',
#   'male',
#   0,
#   7,
#   1,
#   1,
#   'Artist',
#   98,
#   85,
#   75,
#   66,
#   73,
#   88,
#   85,
#   570),
#  (963,
#   'Hunter',
#   'Miller',
#   'hunter.miller.963@gslingacademy.com',
#   'male',
#   0,
#   0,
#   0,
#   2,
#   'Game Developer',
#   80,
#   84,
#   94,
#   63,
#   62,
#   72,
#   68,
#   523),
#  (964,
#   'Shelia',
#   'Rogers',
#   'shelia.rogers.964@gslingacademy.com',
#   'female',
#   0,
#   1,
#   0,
#   35,
#   'Writer',
#   89,
#   91,
#   96,
#   100,
#   95,
#   93,
#   86,
#   650),
#  (965,
#   'Laura',
#   'Walker',
#   'laura.walker.965@gslingacademy.com',
#   'female',
#   0,
#   0,
#   0,
#   5,
#   'Software Engineer',
#   96,
#   67,
#   74,
#   90,
#   75,
#   95,
#   83,
#   580),
#  (966,
#   'Ashley',
#   'Green',
#   'ashley.green.966@gslingacademy.com',
#   'female',
#   0,
#   4,
#   0,
#   14,
#   'Accountant',
#   94,
#   82,
#   80,
#   80,
#   33,
#   93,
#   78,
#   540),
#  (967,
#   'Beth',
#   'Bonilla',
#   'beth.bonilla.967@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   26,
#   'Software Engineer',
#   64,
#   65,
#   97,
#   96,
#   80,
#   80,
#   78,
#   560),
#  (968,
#   'Ray',
#   'Padilla',
#   'ray.padilla.968@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   41,
#   'Doctor',
#   89,
#   89,
#   100,
#   96,
#   96,
#   85,
#   92,
#   647),
#  (969,
#   'Jennifer',
#   'Cummings',
#   'jennifer.cummings.969@gslingacademy.com',
#   'female',
#   0,
#   2,
#   1,
#   6,
#   'Software Engineer',
#   97,
#   78,
#   99,
#   88,
#   69,
#   98,
#   60,
#   589),
#  (970,
#   'Daniel',
#   'Peterson',
#   'daniel.peterson.970@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   35,
#   'Software Engineer',
#   91,
#   97,
#   87,
#   93,
#   94,
#   90,
#   88,
#   640),
#  (971,
#   'Andrew',
#   'Miller',
#   'andrew.miller.971@gslingacademy.com',
#   'male',
#   0,
#   0,
#   1,
#   30,
#   'Construction Engineer',
#   96,
#   98,
#   99,
#   65,
#   95,
#   76,
#   68,
#   597),
#  (972,
#   'Scott',
#   'Jacobson',
#   'scott.jacobson.972@gslingacademy.com',
#   'male',
#   0,
#   2,
#   1,
#   12,
#   'Banker',
#   81,
#   68,
#   97,
#   86,
#   90,
#   78,
#   80,
#   580),
#  (973,
#   'Jennifer',
#   'Baker',
#   'jennifer.baker.973@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   29,
#   'Software Engineer',
#   87,
#   89,
#   61,
#   66,
#   72,
#   90,
#   61,
#   526),
#  (974,
#   'Suzanne',
#   'Morrow',
#   'suzanne.morrow.974@gslingacademy.com',
#   'female',
#   1,
#   9,
#   1,
#   4,
#   'Business Owner',
#   67,
#   56,
#   77,
#   93,
#   95,
#   50,
#   74,
#   512),
#  (975,
#   'Melissa',
#   'Gonzales',
#   'melissa.gonzales.975@gslingacademy.com',
#   'female',
#   1,
#   2,
#   0,
#   0,
#   'Artist',
#   100,
#   95,
#   60,
#   89,
#   77,
#   89,
#   67,
#   577),
#  (976,
#   'Erik',
#   'Miller',
#   'erik.miller.976@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   17,
#   'Software Engineer',
#   88,
#   74,
#   60,
#   60,
#   78,
#   94,
#   69,
#   523),
#  (977,
#   'Pamela',
#   'Flores',
#   'pamela.flores.977@gslingacademy.com',
#   'female',
#   0,
#   1,
#   1,
#   20,
#   'Software Engineer',
#   86,
#   64,
#   100,
#   76,
#   99,
#   77,
#   86,
#   588),
#  (978,
#   'Amanda',
#   'Hernandez',
#   'amanda.hernandez.978@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   35,
#   'Scientist',
#   85,
#   87,
#   90,
#   88,
#   87,
#   97,
#   100,
#   634),
#  (979,
#   'Gregory',
#   'Schaefer',
#   'gregory.schaefer.979@gslingacademy.com',
#   'male',
#   0,
#   2,
#   0,
#   26,
#   'Software Engineer',
#   93,
#   95,
#   80,
#   88,
#   83,
#   62,
#   65,
#   566),
#  (980,
#   'Annette',
#   'Logan',
#   'annette.logan.980@gslingacademy.com',
#   'female',
#   0,
#   3,
#   1,
#   24,
#   'Software Engineer',
#   80,
#   66,
#   77,
#   81,
#   99,
#   99,
#   83,
#   585),
#  (981,
#   'Tamara',
#   'Long',
#   'tamara.long.981@gslingacademy.com',
#   'female',
#   1,
#   6,
#   0,
#   0,
#   'Business Owner',
#   56,
#   67,
#   57,
#   79,
#   87,
#   89,
#   89,
#   524),
#  (982,
#   'John',
#   'Baker',
#   'john.baker.982@gslingacademy.com',
#   'male',
#   0,
#   7,
#   0,
#   32,
#   'Construction Engineer',
#   87,
#   62,
#   84,
#   96,
#   69,
#   98,
#   64,
#   560),
#  (983,
#   'Justin',
#   'Lynch',
#   'justin.lynch.983@gslingacademy.com',
#   'male',
#   0,
#   4,
#   1,
#   4,
#   'Real Estate Developer',
#   97,
#   85,
#   96,
#   61,
#   97,
#   79,
#   70,
#   585),
#  (984,
#   'Daniel',
#   'Knight',
#   'daniel.knight.984@gslingacademy.com',
#   'male',
#   0,
#   3,
#   0,
#   34,
#   'Scientist',
#   86,
#   67,
#   98,
#   86,
#   86,
#   83,
#   89,
#   595),
#  (985,
#   'Angelica',
#   'Jones',
#   'angelica.jones.985@gslingacademy.com',
#   'female',
#   1,
#   3,
#   0,
#   29,
#   'Software Engineer',
#   97,
#   85,
#   81,
#   71,
#   62,
#   62,
#   82,
#   540),
#  (986,
#   'Lance',
#   'Nelson',
#   'lance.nelson.986@gslingacademy.com',
#   'male',
#   0,
#   2,
#   1,
#   35,
#   'Software Engineer',
#   91,
#   94,
#   97,
#   97,
#   100,
#   88,
#   99,
#   666),
#  (987,
#   'Katherine',
#   'Jacobson',
#   'katherine.jacobson.987@gslingacademy.com',
#   'female',
#   0,
#   5,
#   0,
#   23,
#   'Software Engineer',
#   86,
#   64,
#   96,
#   84,
#   86,
#   96,
#   92,
#   604),
#  (988,
#   'Corey',
#   'Taylor',
#   'corey.taylor.988@gslingacademy.com',
#   'male',
#   1,
#   8,
#   0,
#   5,
#   'Business Owner',
#   90,
#   97,
#   54,
#   59,
#   82,
#   76,
#   72,
#   530),
#  (989,
#   'Laura',
#   'Russell',
#   'laura.russell.989@gslingacademy.com',
#   'female',
#   0,
#   0,
#   0,
#   1,
#   'Game Developer',
#   95,
#   87,
#   87,
#   84,
#   95,
#   84,
#   65,
#   597),
#  (990,
#   'Arthur',
#   'Harris',
#   'arthur.harris.990@gslingacademy.com',
#   'male',
#   0,
#   1,
#   0,
#   31,
#   'Banker',
#   90,
#   100,
#   76,
#   76,
#   84,
#   79,
#   84,
#   589),
#  (991,
#   'Victoria',
#   'Garcia',
#   'victoria.garcia.991@gslingacademy.com',
#   'female',
#   0,
#   1,
#   1,
#   14,
#   'Software Engineer',
#   66,
#   68,
#   87,
#   70,
#   77,
#   76,
#   89,
#   533),
#  (992,
#   'David',
#   'Gonzales',
#   'david.gonzales.992@gslingacademy.com',
#   'male',
#   0,
#   6,
#   0,
#   3,
#   'Business Owner',
#   81,
#   92,
#   72,
#   91,
#   67,
#   71,
#   88,
#   562),
#  (993,
#   'Charles',
#   'Thomas',
#   'charles.thomas.993@gslingacademy.com',
#   'male',
#   1,
#   2,
#   0,
#   18,
#   'Software Engineer',
#   85,
#   99,
#   86,
#   69,
#   68,
#   98,
#   62,
#   567),
#  (994,
#   'Oscar',
#   'Gonzalez',
#   'oscar.gonzalez.994@gslingacademy.com',
#   'male',
#   0,
#   1,
#   1,
#   47,
#   'Doctor',
#   94,
#   90,
#   95,
#   85,
#   98,
#   91,
#   96,
#   649),
#  (995,
#   'Sarah',
#   'Miller',
#   'sarah.miller.995@gslingacademy.com',
#   'female',
#   0,
#   2,
#   0,
#   4,
#   'Game Developer',
#   81,
#   71,
#   83,
#   63,
#   80,
#   79,
#   83,
#   540),
#  (996,
#   'Eric',
#   'Davis',
#   'eric.davis.996@gslingacademy.com',
#   'male',
#   1,
#   1,
#   1,
#   32,
#   'Software Engineer',
#   97,
#   87,
#   95,
#   67,
#   98,
#   93,
#   89,
#   626),
#  (997,
#   'Patrick',
#   'Martin',
#   'patrick.martin.997@gslingacademy.com',
#   'male',
#   0,
#   3,
#   1,
#   20,
#   'Accountant',
#   100,
#   79,
#   72,
#   98,
#   87,
#   76,
#   76,
#   588),
#  (998,
#   'Susan',
#   'Schmidt',
#   'susan.schmidt.998@gslingacademy.com',
#   'female',
#   1,
#   6,
#   0,
#   3,
#   'Business Owner',
#   54,
#   64,
#   72,
#   80,
#   98,
#   83,
#   85,
#   536),
#  (999,
#   'Brett',
#   'Bell',
#   'brett.bell.999@gslingacademy.com',
#   'male',
#   1,
#   5,
#   0,
#   19,
#   'Software Engineer',
#   97,
#   87,
#   70,
#   74,
#   73,
#   74,
#   81,
#   556),
#  (1000,
#   'Dennis',
#   'Summers',
#   'dennis.summers.1000@gslingacademy.com',
#   'male',
#   0,
#   1,
#   1,
#   5,
#   'Real Estate Developer',
#   65,
#   83,
#   67,
#   84,
#   89,
#   65,
#   73,
#   526),
#  ...]
